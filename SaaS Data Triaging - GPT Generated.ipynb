# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ### Prompt Used to generate SaaS Training Dataset:
#
# Can you help me generate a long list customer requests that come in for some Saas company that has to be triaged to different departments like product teams, support teams, finance teams etc. Could you make the requests or questions from customers as realistic as possible. Provide the answer in terms of the question asked and the team the request needs to be triaged to.

# %%
saas_data = "/Users/abhishekkarmakar/Desktop/TAGGING/GPT based triaging.txt"

# %%
requests, teams = [], []

with open(saas_data, "r") as file:
    lines = file.readlines()
    for line in lines:
        if line.startswith("Request:"):
            request = line.split("Request:", 1)[1].strip()
            request = request.strip('"') # This line removes the quotation marks
            requests.append(request)
        elif line.startswith("Team:"):
            teams.append(line.split("Team:", 1)[1].strip())

# %%
df = pd.DataFrame({
    'Request': requests,
    'Team': teams
})

df['Team'].value_counts()
# Out:
# Support Team                460
# Finance Team                459
# Product Development Team    458
# Sales Team                   17
# Training Team                 6
# Marketing Team                5
# Legal Team                    5
# Security Team                 4
# IT Operations Team            4
# Implementation Team           2
# Finance                       1
# Name: Team, dtype: int64

# %%
df = df[(df['Team'] == 'Support Team') | (df['Team'] == 'Finance Team') | (df['Team'] == 'Product Development Team')]

# %%
df['Team'].value_counts()
# Out:
# Support Team                460
# Finance Team                459
# Product Development Team    458
# Name: Team, dtype: int64

# %%
df
# Out:
#                                                                                                                                                                                                      Request  \
# 0                                                                                                                                                                I'm having trouble logging into my account.
# 1                                                                                                                                                                     How do I upgrade my subscription plan?
# 2                                                                                                                                                             I noticed a bug in the latest software update.
# 3                                                                                                                                                  I can't find the feature to export my data. Can you help?
# 4                                                                                                                                                     I need assistance integrating the API into my website.
# 5                                                                                                                                                          My payment was declined. What could be the issue?
# 6                                                                                                                                                  Is there a way to track user engagement on the dashboard?
# 7                                                                                                                                                      The application is running slow. Can you optimise it?
# 8                                                                                                                                            I accidentally deleted some important data. Can you recover it?
# 9                                                                                                                                                   What payment methods do you accept for the subscription?
# 10                                                                                                                                                                          How do I cancel my subscription?
# 11                                                                                                                                                            Can you add multi-language support to the app?
# 12                                                                                                                                                The invoices I received are incorrect. Please revise them.
# 13                                                                                                                                                     I need a refund for a duplicate charge on my account.
# 14                                                                                                                                                Is there a mobile app version available for your software?
# 15                                                                                                                                           I have a suggestion for a new feature. Who can I share it with?
# 16                                                                                                                                                                  How can I update my billing information?
# 17                                                                                                                                          The user interface is confusing. Can you make it more intuitive?
# 18                                                                                                                                                         I can't access my files. Is there a server issue?
# 19                                                                                                                                                 What are the system requirements for using your software?
# 20                                                                                                                        My trial period ended, but I need a few more days to evaluate. Can it be extended?
# 21                                                                                                                                                             Is there a way to automate report generation?
# 22                                                                                                                                                     I'm not receiving email notifications. Can you check?
# 23                                                                                                                                     Can I switch my subscription plan in the middle of the billing cycle?
# 24                                                                                                                                             The app crashed, and I lost unsaved work. Can you recover it?
# 25                                                                                                                                              What security measures do you have in place to protect data?
# 26                                                                                                                                                                  I need an invoice for my recent payment.
# 27                                                                                                                                   The software is not compatible with my operating system. What can I do?
# 28                                                                                                                                                                   Is there a way to export data to Excel?
# 29                                                                                                                                                    I have a billing discrepancy. Can you help resolve it?
# 30                                                                                                                                                                How can I change my account email address?
# 31                                                                                                                                       The analytics dashboard is not updating in real-time. What's wrong?
# 32                                                                                                                                   I'm not sure how to use a specific feature. Can you provide a tutorial?
# 33                                                                                                                                                     Do you offer a student discount for the subscription?
# 34                                                                                                                                            The software is giving me an error message. What does it mean?
# 35                                                                                                                                   I need help setting up my account and configuring the initial settings.
# 36                                                                                                                                                           I've forgotten my password. How can I reset it?
# 37                                                                                                                                        Is there a way to customize the email templates for notifications?
# 38                                                                                                                                         I'd like to request a refund for a subscription I no longer need.
# 39                                                                                                                                            The software is not syncing across my devices. Can you fix it?
# 40                                                                                                                                        Can you provide documentation on the API endpoints and parameters?
# 41                                                                                                                                            My credit card was charged multiple times. Please investigate.
# 42                                                                                                                           I have a suggestion for improving the user interface. Where should I submit it?
# 43                                                                                                                                                    How can I export a report of all my past transactions?
# 44                                                                                                                                            The software crashes whenever I try to print a document. Help!
# 45                                                                                                                                                        Can you add support for two-factor authentication?
# 46                                                                                                                                     I received an error message while making a payment. What should I do?
# 47                                                                                                                                                 Is there a way to schedule automated backups for my data?
# 48                                                                                                                                                             I need a copy of my invoice for tax purposes.
# 49                                                                                                                               The search functionality is not returning relevant results. Fix it, please.
# 50                                                                                                                                                    Can you help me migrate my data from another software?
# 51                                                                                                                                            I accidentally deleted a crucial project. Can it be recovered?
# 52                                                                                                                              I'd like to change my subscription plan to a higher tier. How can I do that?
# 53                                                                                                                                      The software is displaying outdated information. Can you refresh it?
# 54                                                                                                                                          I'm having trouble canceling my subscription. Can you assist me?
# 55                                                                                                                                    The app's performance is sluggish on my mobile device. Fix it, please.
# 56                                                                                                                                        I can't find the invoice for my recent payment. Can you resend it?
# 57                                                                                                                                  How can I add multiple users to my account with different access levels?
# 58                                                                                                                                      I believe I was overcharged for my subscription. Please investigate.
# 59                                                                                                                                      The software is displaying the wrong timezone. How can I correct it?
# 60                                                                                                                                 I need assistance with integrating third-party plugins into the software.
# 61                                                                                                                                          What are the different payment options available for my country?
# 62                                                                                                                                         The data visualizations in the analytics module need improvement.
# 63                                                                                                                                    My subscription was canceled, but I didn't initiate it. Can you check?
# 64                                                                                                                                              Is there a way to download a copy of the user activity logs?
# 65                                                                                                                                          I'm encountering a runtime error while using the software. Help!
# 66                                                                                                                                                   How do I update my billing address for future invoices?
# 67                                                                                                                                      The software's mobile app is missing some features. Please add them.
# 68                                                                                                                                                 I need a detailed breakdown of the charges on my invoice.
# 69                                                                                                                                            The knowledge base articles are outdated. Can you update them?
# 70                                                                                                                                             I'm unable to upload files to the cloud storage. Please help!
# 71                                                                                                                                            Is there a way to integrate your software with our CRM system?
# 72                                                                                                                        I want to change my subscription plan to a yearly billing cycle. How do I do that?
# 73                                                                                                                                The software's performance is slow during peak hours. Can you optimize it?
# 74                                                                                                                                 I accidentally made a purchase on the wrong account. Can you transfer it?
# 75                                                                                                                            I'm getting a 404 error when trying to access a specific page. Fix it, please.
# 76                                                                                                                                               How can I export my contacts from the address book feature?
# 77                                                                                                                    I need an extension on my trial period. It's not enough time to evaluate the software.
# 78                                                                                                                                   Is there a way to set up automated email campaigns using your software?
# 79                                                                                                                                         I'm having trouble with the payment gateway. Can you investigate?
# 80                                                                                                                                                 How can I downgrade my subscription plan to a lower tier?
# 81                                                                                                                                     The software is not compatible with my browser. Can you make it work?
# 82                                                                                                                               I need assistance in customizing the reports to fit our company's branding.
# 83                                                                                                                             I didn't receive the renewal reminder for my subscription. Can you resend it?
# 84                                                                                                                            The user permissions are not working correctly. Can you fix the access levels?
# 85                                                                                                                                  I've encountered a security issue with the software. How do I report it?
# 86                                                                                                                                   Can I get a discount for subscribing to multiple licenses for our team?
# 87                                                                                                                    The software's UI is not responsive on mobile devices. Please make it mobile-friendly.
# 88                                                                                                                                                   How can I add a new user to our organization's account?
# 89                                                                                                                                         I need a breakdown of my monthly usage and its impact on billing.
# 90                                                                                                                                           The password reset link is not working. Can you send a new one?
# 91                                                                                                                                          Do you offer training sessions to get started with the software?
# 92                                                                                                                                        I need to update my credit card information for automatic billing.
# 93                                                                                                                                         The software's mobile app is crashing frequently. Fix it, please.
# 94                                                                                                                                           How can I export my data from the software for backup purposes?
# 95                                                                                                                                       I believe there's an error in my invoice amount. Can you review it?
# 96                                                                                                                                      The software is not sending email notifications for new tasks. Help!
# 97                                                                                                                                       I need to renew my subscription, but I can't find the payment link.
# 98                                                                                                                                        Is there a way to track user activity in real-time within the app?
# 99                                                                                                                                   I'm having difficulty importing data from a CSV file. Can you guide me?
# 100                                                                                                                                       Can you provide a breakdown of features in each subscription plan?
# 101                                                                                                              The software's user interface is not accessible for visually impaired users. Please fix it.
# 102                                                                                                                                                          How do I update my billing contact information?
# 103                                                                                                                                I need help troubleshooting an issue with the software's API integration.
# 104                                                                                                                                   What are the system requirements for running the software on-premises?
# 105                                                                                                                     I'm having trouble accessing the software from my workplace network. Can you assist?
# 106                                                                                                                We need a custom integration with our internal project management tool. Is that possible?
# 107                                                                                                                                        I accidentally canceled my subscription. How can I reactivate it?
# 108                                                                                                                              The software's chat feature is not working. Can you investigate and fix it?
# 109                                                                                                                                Can you provide guidance on how to set up recurring invoices for clients?
# 110                                                                                                                                      There was an unauthorized charge on my account. Help me resolve it.
# 111                                                                                                                      I'd like to suggest adding a dark mode option to the software for better usability.
# 112                                                                                                                  The software's performance is affected during peak hours. Can you optimize the servers?
# 113                                                                                                                                 How can I export my customer data for analysis in a spreadsheet program?
# 114                                                                                                               We need an invoice with specific details for our accounting records. Can you customize it?
# 115                                                                                                                               The software's dashboard is not displaying real-time data. Can you fix it?
# 116                                                                                                                    I encountered a bug that resulted in data loss. Can you recover the lost information?
# 117                                                                                                                          Is there a way to get a discount for purchasing an annual subscription upfront?
# 118                                                                                                                             I need help setting up automatic backups for our database. Can you guide me?
# 119                                                                                                                             Can you provide documentation on how to use the API for custom integrations?
# 120                                                                                                             My team members are experiencing difficulty accessing shared files. Can you troubleshoot it?
# 121                                                                                                                          I have a billing dispute regarding the charges on my account. Please review it.
# 122                                                                                                                 The software is not sending email notifications for task reminders. Can you investigate?
# 123                                                                                                                           How do I transfer my subscription to a different user within our organization?
# 124                                                                                                                    The software's knowledge base needs updated articles and better search functionality.
# 125                                                                                                                                  I'd like to request a refund for the unused portion of my subscription.
# 126                                                                                                                                         Can you add the option to assign tasks to multiple team members?
# 127                                                                                                                                   I need help migrating my existing data from another software to yours.
# 128                                                                                                                          The software's mobile app crashes upon opening. Can you investigate and fix it?
# 129                                                                                                                                           How can I change the email address associated with my account?
# 130                                                                                                                             I need assistance in setting up a custom domain for the white-label feature.
# 131                                                                                                                          The subscription auto-renewal charged the wrong credit card. Please correct it.
# 132                                                                                                                                  Can you provide guidance on how to use the advanced reporting features?
# 133                                                                                                                     I've discovered a security vulnerability in the software. Who should I report it to?
# 134                                                                                                                           I need to update my company's billing address for invoices. How can I do that?
# 135                                                                                                                              The software's user interface is not intuitive. Can you improve the design?
# 136                                                                                                                  How can I grant temporary access to a team member without sharing my login credentials?
# 137                                                                                                                        I received an error while upgrading my subscription plan. Please help me upgrade.
# 138                                                                                                                            Is there a way to set up role-based access control for different user groups?
# 139                                                                                                              I'm interested in your software's API capabilities. Where can I find the API documentation?
# 140                                                                     I'm trying to connect my software to a third-party tool via API, but I'm encountering authentication errors. How can I resolve this?
# 141                                                                             I've noticed a discrepancy between the number of users in my subscription and the actual usage. Can you help me align these?
# 142                                                                                      The software's mobile app interface doesn't match the desktop version. Can you ensure consistency across platforms?
# 143                                                                              I'm interested in exploring the software's advanced analytics features. Could you guide me through creating custom reports?
# 144                                                                                                 We need to upgrade our storage capacity due to increased data usage. How can we adjust our subscription?
# 145                                                                                 I'm facing difficulties in exporting my project data into a specific format. Can you assist me with this export process?
# 146                                                                                               Our team requires access to more specific user roles and permissions. How can we customize these settings?
# 147                                                                                I've noticed that the software's response time has decreased recently. Could you investigate the performance degradation?
# 148                                                                                           I need assistance in setting up single sign-on (SSO) for our organization's account. Can you provide guidance?
# 149                                                                                              I've experienced a sudden loss of connection to the software. Is there a server issue or is this on my end?
# 150                                                                              Our team would like to integrate our proprietary CRM system with your software. Can you help us establish this integration?
# 151                                                                                                   I'd like to change the primary contact associated with our account. How can I update this information?
# 152                                                                                                  The software's user interface is not optimized for touchscreens. Could you make it more touch-friendly?
# 153                                                                   We've identified a need for more extensive user training on using advanced features. Can you arrange for additional training sessions?
# 154                                                                                  We've encountered an issue where the software is duplicating records. Can you assist in identifying and resolving this?
# 155                                                                                       I need a breakdown of the taxes applied to our subscription charges for accounting purposes. Can you provide that?
# 156                                                                                                  I'd like to switch from monthly to quarterly billing for our subscription. How can we make this change?
# 157                                                                                           The software's color scheme doesn't align with our brand identity. Can you provide options for customizing it?
# 158                                                                                            I'm facing issues with setting up the software's notification system. Can you help me configure it correctly?
# 159                                                                            We've discovered that certain features of the software are not compliant with our industry regulations. Can you address this?
# 160                                                                                                                          How can I export a detailed audit trail of user activities within the software?
# 161                                                                             We need to make adjustments to our subscription billing cycle due to changes in our financial reporting. How can we do that?
# 162                                                                                             The software's search functionality is not providing accurate results. Can you improve its search algorithm?
# 163                                                                                      I'm encountering issues while trying to import large datasets into the software. Is there a size limit for imports?
# 164                                                                                        We're interested in exploring the possibility of white-labeling the software for our clients. How can we proceed?
# 165                                                                      I'm having trouble with the software's search feature not returning accurate results for specific keywords. How can I improve this?
# 166                                                                                                                           I accidentally deleted a critical project in the software. Can it be restored?
# 167                                               Our company is going through a rebranding process, and we'd like to update the software's interface with our new colors and logo. How can we achieve this?
# 168                                                                  I'm experiencing slow response times when using the software on certain browsers. Can you optimize its performance across all browsers?
# 169                                                                                             The invoices I received don't match the agreed-upon pricing in our contract. Can you review and adjust them?
# 170                                                                               I need assistance in creating custom workflows within the software to match our team's unique processes. Can you guide me?
# 171                                                                           The software's mobile app lacks some features available on the web version. How can we ensure feature parity across platforms?
# 172                                                                                          I'm having issues with integration between your software and our CRM system. Can you provide technical support?
# 173                                                                                            We'd like to add more administrators to our organization's account. How can we manage user roles effectively?
# 174                                                                       We have several team members who are unable to log into the software despite using correct credentials. Can you troubleshoot this?
# 175                                                         The software's reporting feature doesn't provide the level of detail we need for our analytics. Can we request additional customization options?
# 176                                                                            I've identified a security vulnerability in the software's authentication process. Where can I report this for prompt action?
# 177                                                 Our organization needs to allocate costs to different departments within our subscription. Can we generate customized usage reports for each department?
# 178                                                                                                   The software's UI is not fully responsive on small screens. Can you enhance its mobile responsiveness?
# 179                                                                                          We've encountered issues while importing data into the software. Is there a data validation step we're missing?
# 180                                                                                     Our company is expanding globally, and we need to adjust the currency used for billing. How can we make this change?
# 181                                                                                      The software's auto-save feature isn't working as expected, leading to data loss. Can you investigate and fix this?
# 182                                                       We've noticed that certain email notifications from the software are landing in recipients' spam folders. How can we improve email deliverability?
# 183                                                                               Our subscription renewal date needs to be moved to align with our financial calendar. How can we adjust the billing cycle?
# 184                                                                                        I'm interested in setting up custom user permissions for specific features within the software. Is this possible?
# 185                                                                                  The software's onboarding process lacks clarity, causing confusion for new users. Can you provide a step-by-step guide?
# 186                                                                                We'd like to offer a trial period extension to a specific group of customers. How can we manage this on the billing side?
# 187                                                                                            The software's export functionality is missing some critical data fields. Can you enhance the export options?
# 188                                                                                         I'm encountering issues when trying to sync our data with the software's API. Can you assist in troubleshooting?
# 189                                                                    Our company policy requires detailed logs of user activities within the software. How can we access these logs for auditing purposes?
# 190                                                                 We need to generate custom reports that provide insights into user engagement patterns within the software. How can we access this data?
# 191                                                                                                     I'm encountering difficulties in exporting large datasets. Is there a limit on the data export size?
# 192                                                                                        Our organization is changing billing contacts. How can we update the billing contact information for our account?
# 193                                                                                             The software's collaboration features are not working as expected. How can we troubleshoot and resolve this?
# 194                                            We'd like to implement a custom workflow that involves integrating data from our internal databases with the software. Can you guide us through this process?
# 195                                                             We're experiencing a discrepancy in the usage statistics reported in the software compared to our actual usage. Can you help reconcile this?
# 196                                                                                      I'm interested in migrating our existing data to your software. What is the recommended process for data migration?
# 197                                                                  The software's password recovery process is not working for some of our team members. Can you assist them in recovering their accounts?
# 198                                                                          We've identified a need for additional data visualization options within the software. Can you explore adding more chart types?
# 199                                                                                      Our team is expanding, and we need to add new users to the software. How can we efficiently onboard multiple users?
# 200                                                           We need to allocate costs from our subscription to different cost centers. Can you provide usage reports that break down costs per department?
# 201                                                                                              The software's file upload feature is not working consistently. Can you investigate and resolve this issue?
# 202                                                                I'm trying to integrate the software with our CRM, but I can't find the necessary API documentation. Where can I access this information?
# 203                                                                              Our financial team is requesting a detailed breakdown of our subscription charges. Can you provide a more itemized invoice?
# 204                                                                                        The software's performance seems to degrade during heavy usage. How can we optimize it to handle increased loads?
# 205                                                 We're interested in offering our customers the ability to schedule appointments using the software. Can you help us set up appointment booking features?
# 206                                                                     We've experienced a sudden loss of connectivity to the software, but other web services are working fine. Could this be on your end?
# 207                                                                                     We need to update the payment method for our subscription. How can we ensure a smooth transition without disruption?
# 208                                                                                        The software's data export option is missing some fields we need for analysis. Can you expand the export options?
# 209                                                      I'm encountering issues while trying to configure automated email notifications for specific triggers. Can you provide guidance on setting this up?
# 210                                                                                 We'd like to set up custom billing cycles for different client projects. Is there flexibility in the billing scheduling?
# 211                                                                              The software's user interface is not intuitive for new users. Can you offer training resources to help us onboard our team?
# 212                                         We've discovered a discrepancy between the software's data analytics and our internal analytics platform. Can you help us identify the source of the difference?
# 213                                                                                            Our organization needs to update the company logo displayed within the software. How can we make this change?
# 214                                                                            We're interested in exploring customization options for the software's reporting templates. Is this something we can request?
# 215                                                                                We're encountering issues while integrating our software with your API. Is there a developer support team we can contact?
# 216                                                                   The software's notification emails are getting marked as spam by our email provider. Can you help us improve the email deliverability?
# 217                                                         We need to set up user access controls that restrict certain team members from accessing sensitive data. How can we configure these permissions?
# 218                                                                The software's documentation is not up-to-date with the latest features. Can you ensure that the help resources are accurate and current?
# 219                                                                We've made changes to our company's credit card, and we need to update it for subscription billing. How can we update the payment method?
# 220                                                    I'm having difficulty in exporting data in a specific format that aligns with our reporting requirements. Can you provide guidance on custom exports?
# 221                                                                                Our team would like to set up custom automated workflows based on certain triggers within the software. Is this possible?
# 222                                                                                        We need to adjust our subscription plan to accommodate additional users. Can you assist us in making this change?
# 223                                                      The software's user interface is too cluttered, making it difficult for our team to navigate. Can you optimize the UI for improved user experience?
# 224                                                                               I've encountered an error message when trying to process a payment. Can you help me troubleshoot and complete the payment?
# 225                                                  Our organization has specific branding guidelines, and we'd like to customize the software's appearance to match our branding. How can we achieve this?
# 226                                                                         We need to generate a comprehensive usage report for our subscription. Can you help us access this data for financial reporting?
# 227                                                                                              The software's response time has been slower lately. Can you investigate and address the performance issue?
# 228                                                                                                   I'm facing difficulties when trying to upload large files to the software. Is there a file size limit?
# ...
# 936   Product Development Team
# 937   Product Development Team
# 938   Product Development Team
# 939               Support Team
# 940               Support Team
# 941               Support Team
# 942               Support Team
# 943               Support Team
# 944               Finance Team
# 945               Finance Team
# 946               Finance Team
# 947               Finance Team
# 948               Finance Team
# 949   Product Development Team
# 950   Product Development Team
# 951   Product Development Team
# 952   Product Development Team
# 953   Product Development Team
# 954               Support Team
# 955               Support Team
# 956               Support Team
# 957               Support Team
# 958               Support Team
# 959               Finance Team
# 960               Finance Team
# 961               Finance Team
# 962               Finance Team
# 963               Finance Team
# 964   Product Development Team
# 965   Product Development Team
# 966   Product Development Team
# 967   Product Development Team
# 968   Product Development Team
# 969               Support Team
# 970               Support Team
# 971               Support Team
# 972               Support Team
# 973               Support Team
# 974               Finance Team
# 975               Finance Team
# 976               Finance Team
# 977               Finance Team
# 978               Finance Team
# 979   Product Development Team
# 980   Product Development Team
# 981   Product Development Team
# 982   Product Development Team
# 983   Product Development Team
# 984               Support Team
# 985               Support Team
# 986               Support Team
# 987               Support Team
# 988               Support Team
# 989               Finance Team
# 990               Finance Team
# 991               Finance Team
# 992               Finance Team
# 993               Finance Team
# 994   Product Development Team
# 995   Product Development Team
# 996   Product Development Team
# 997   Product Development Team
# 998   Product Development Team
# 999               Support Team
# 1000              Support Team
# 1001              Support Team
# 1002              Support Team
# 1003              Support Team
# 1004              Finance Team
# 1005              Finance Team
# 1006              Finance Team
# 1007              Finance Team
# 1008              Finance Team
# 1009              Finance Team
# 1010              Finance Team
# 1011              Finance Team
# 1012              Finance Team
# 1013              Finance Team
# 1014              Finance Team
# 1015              Finance Team
# 1016              Finance Team
# 1017              Finance Team
# 1019              Finance Team
# 1020              Finance Team
# 1021              Finance Team
# 1022              Finance Team
# 1023              Finance Team
# 1024              Finance Team
# 1025              Finance Team
# 1026              Finance Team
# 1027              Finance Team
# 1028              Finance Team
# 1029              Finance Team
# 1030              Finance Team
# 1031              Finance Team
# 1032              Finance Team
# 1033              Finance Team
# 1034              Finance Team
# 1035              Finance Team
# 1036              Finance Team
# 1037              Finance Team
# 1038              Finance Team
# 1039              Finance Team
# 1040              Finance Team
# 1041              Finance Team
# 1042              Finance Team
# 1043              Finance Team
# 1044              Finance Team
# 1045              Finance Team
# 1046              Finance Team
# 1047              Finance Team
# 1048              Finance Team
# 1049              Finance Team
# 1050              Finance Team
# 1051              Finance Team
# 1052              Finance Team
# 1053              Finance Team
# 1054              Finance Team
# 1055              Finance Team
# 1056              Finance Team
# 1057              Finance Team
# 1058              Finance Team
# 1059              Finance Team
# 1060              Finance Team
# 1061              Finance Team
# 1062              Finance Team
# 1063              Finance Team
# 1064              Finance Team
# 1065              Finance Team
# 1066              Finance Team
# 1067              Finance Team
# 1068              Finance Team
# 1069              Finance Team
# 1070              Finance Team
# 1071              Finance Team
# 1072              Finance Team
# 1073              Finance Team
# 1074              Finance Team
# 1075              Finance Team
# 1076              Finance Team
# 1077              Finance Team
# 1078              Finance Team
# 1079              Finance Team
# 1080              Finance Team
# 1081              Finance Team
# 1082              Finance Team
# 1083              Finance Team
# 1084              Finance Team
# 1085              Finance Team
# 1086              Finance Team
# 1087              Finance Team
# 1088              Finance Team
# 1089              Finance Team
# 1090              Finance Team
# 1091              Finance Team
# 1092              Finance Team
# 1093              Finance Team
# 1094              Finance Team
# 1095              Finance Team
# 1096              Finance Team
# 1097              Finance Team
# 1098              Finance Team
# 1099              Finance Team
# 1100              Finance Team
# 1101              Finance Team
# 1102              Finance Team
# 1103              Finance Team
# 1104              Finance Team
# 1105              Finance Team
# 1106              Finance Team
# 1107              Finance Team
# 1108              Finance Team
# 1109              Finance Team
# 1110              Finance Team
# 1111              Finance Team
# 1112              Finance Team
# 1113              Finance Team
# 1114              Finance Team
# 1115              Finance Team
# 1116              Finance Team
# 1117              Finance Team
# 1118              Finance Team
# 1119              Finance Team
# 1120              Finance Team
# 1121              Finance Team
# 1122              Finance Team
# 1123              Finance Team
# 1124              Finance Team
# 1125              Finance Team
# 1126              Finance Team
# 1127              Finance Team
# 1128              Finance Team
# 1129              Finance Team
# 1130              Finance Team
# 1131              Finance Team
# 1132              Finance Team
# 1133              Finance Team
# 1134              Finance Team
# 1135              Finance Team
# 1136              Finance Team
# 1137              Finance Team
# 1138              Finance Team
# 1139              Finance Team
# 1140              Finance Team
# 1141              Finance Team
# 1142              Finance Team
# 1143              Finance Team
# 1144              Support Team
# 1145              Support Team
# 1146              Support Team
# 1147              Support Team
# 1148              Support Team
# 1149              Support Team
# 1150              Support Team
# 1151              Support Team
# 1152              Support Team
# 1153              Support Team
# 1154              Support Team
# 1155              Support Team
# 1156              Support Team
# 1157              Support Team
# 1158              Support Team
# 1159              Support Team
# 1160              Support Team
# 1161              Support Team
# 1162              Support Team
# 1163              Support Team
# 1164              Support Team
# 1165              Support Team
# 1166              Support Team
# 1167              Support Team
# 1168              Support Team
# 1169              Finance Team
# 1170              Finance Team
# 1171              Finance Team
# 1172              Finance Team
# 1173              Finance Team
# 1174              Finance Team
# 1175              Finance Team
# 1176              Finance Team
# 1177              Finance Team
# 1178              Finance Team
# 1179              Support Team
# 1180              Support Team
# 1181              Support Team
# 1182              Support Team
# 1183              Support Team
# 1184              Support Team
# 1185              Support Team
# 1186              Support Team
# 1187              Support Team
# 1188              Support Team
# 1189              Finance Team
# 1190              Finance Team
# 1191              Finance Team
# 1192              Finance Team
# 1193              Finance Team
# 1194              Finance Team
# 1195              Finance Team
# 1196              Finance Team
# 1197              Finance Team
# 1198              Finance Team
# 1199              Support Team
# 1200              Support Team
# 1201              Support Team
# 1202              Support Team
# 1203              Support Team
# 1204              Support Team
# 1205              Support Team
# 1206              Support Team
# 1207              Support Team
# 1208              Support Team
# 1209              Finance Team
# 1210              Finance Team
# 1211              Finance Team
# 1212              Finance Team
# 1213              Finance Team
# 1214              Finance Team
# 1215              Finance Team
# 1216              Finance Team
# 1217              Finance Team
# 1218              Finance Team
# 1219              Support Team
# 1220              Support Team
# 1221              Support Team
# 1222              Support Team
# 1223              Support Team
# 1224              Support Team
# 1225              Support Team
# 1226              Support Team
# 1227              Support Team
# 1228              Support Team
# 1229              Finance Team
# 1230              Finance Team
# 1231              Finance Team
# 1232              Finance Team
# 1233              Finance Team
# 1234              Finance Team
# 1235              Finance Team
# 1236              Finance Team
# 1237              Finance Team
# 1238              Finance Team
# 1239              Support Team
# 1240              Support Team
# 1241              Support Team
# 1242              Support Team
# 1243              Support Team
# 1244              Support Team
# 1245              Support Team
# 1246              Support Team
# 1247              Support Team
# 1248              Support Team
# 1249              Support Team
# 1250              Support Team
# 1251              Support Team
# 1252              Support Team
# 1253              Support Team
# 1254              Support Team
# 1255              Support Team
# 1256              Support Team
# 1257              Support Team
# 1258              Support Team
# 1259              Support Team
# 1260              Support Team
# 1261              Support Team
# 1262              Support Team
# 1263              Support Team
# 1264              Support Team
# 1265              Support Team
# 1266              Support Team
# 1267              Support Team
# 1268              Support Team
# 1269              Finance Team
# 1270              Finance Team
# 1271              Finance Team
# 1272              Finance Team
# 1273              Finance Team
# 1274              Finance Team
# 1275              Finance Team
# 1276              Finance Team
# 1277              Finance Team
# 1278              Finance Team
# 1279  Product Development Team
# 1280  Product Development Team
# 1281  Product Development Team
# 1282  Product Development Team
# 1283  Product Development Team
# 1284  Product Development Team
# 1285  Product Development Team
# 1286  Product Development Team
# 1287  Product Development Team
# 1288  Product Development Team
# 1289              Support Team
# 1290              Support Team
# 1291              Support Team
# 1292              Support Team
# 1293              Support Team
# 1294              Support Team
# 1295              Support Team
# 1296              Support Team
# 1297              Support Team
# 1298              Support Team
# 1299              Finance Team
# 1300              Finance Team
# 1301              Finance Team
# 1302              Finance Team
# 1303              Finance Team
# 1304              Finance Team
# 1305              Finance Team
# 1306              Finance Team
# 1307              Finance Team
# 1308              Finance Team
# 1309  Product Development Team
# 1310  Product Development Team
# 1311  Product Development Team
# 1312  Product Development Team
# 1313  Product Development Team
# 1314  Product Development Team
# 1315  Product Development Team
# 1316  Product Development Team
# 1317  Product Development Team
# 1318  Product Development Team
# 1319              Support Team
# 1320              Support Team
# 1321              Support Team
# 1322              Support Team
# 1323              Support Team
# 1324              Support Team
# 1325              Support Team
# 1326              Support Team
# 1327              Support Team
# 1328              Support Team
# 1329              Finance Team
# 1330              Finance Team
# 1331              Finance Team
# 1332              Finance Team
# 1333              Finance Team
# 1334              Finance Team
# 1335              Finance Team
# 1336              Finance Team
# 1337              Finance Team
# 1338              Finance Team
# 1339  Product Development Team
# 1340  Product Development Team
# 1341  Product Development Team
# 1342  Product Development Team
# 1343  Product Development Team
# 1344  Product Development Team
# 1345  Product Development Team
# 1346  Product Development Team
# 1347  Product Development Team
# 1348  Product Development Team
# 1349              Support Team
# 1350              Support Team
# 1351              Support Team
# 1352              Support Team
# 1353              Support Team
# 1354              Support Team
# 1355              Support Team
# 1356              Support Team
# 1357              Support Team
# 1358              Support Team
# 1359              Finance Team
# 1360              Finance Team
# 1361              Finance Team
# 1362              Finance Team
# 1363              Finance Team
# 1364              Finance Team
# 1365              Finance Team
# 1366              Finance Team
# 1367  Product Development Team
# 1368  Product Development Team
# 1369  Product Development Team
# 1370  Product Development Team
# 1371  Product Development Team
# 1372  Product Development Team
# 1373  Product Development Team
# 1374  Product Development Team
# 1375  Product Development Team
# 1376              Support Team
# 1377              Support Team
# 1378              Support Team
# 1379              Support Team
# 1380              Support Team
# 1381              Support Team
# 1382              Support Team
# 1383              Support Team
# 1384              Support Team
# 1385              Finance Team
# 1386              Finance Team
# 1387              Finance Team
# 1388              Finance Team
# 1389              Finance Team
# 1390              Finance Team
# 1391              Finance Team
# 1392              Finance Team
# 1393              Finance Team
# 1394  Product Development Team
# 1395  Product Development Team
# 1396  Product Development Team
# 1397  Product Development Team
# 1398  Product Development Team
# 1399  Product Development Team
# 1400  Product Development Team
# 1401  Product Development Team
# 1402  Product Development Team
# 1403              Support Team
# 1404              Support Team
# 1405              Support Team
# 1406              Support Team
# 1407              Support Team
# 1408              Support Team
# 1409              Support Team
# 1410              Support Team
# 1411              Support Team
# 1412              Finance Team
# 1413              Finance Team
# 1414              Finance Team
# 1415              Finance Team
# 1416              Finance Team
# 1417              Finance Team
# 1418              Finance Team
# 1419              Finance Team
# 1420              Finance Team

# %%
# !pip install tensorflow
# !pip install tensorflow_hub

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
import tensorflow_hub as hub

from sklearn.model_selection import GridSearchCV, train_test_split, StratifiedKFold

# %%
module_url = "https://tfhub.dev/google/universal-sentence-encoder/4"
use_model = hub.load(module_url)

# %%
X = df['Request']
y = df['Team']

# %%
X_encoded = list(use_model(X))
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.1, random_state=42)

# %% [markdown]
# ### Support Vector Machine

# %%
param_grid = {
    'C': [5,6,7,8,9],
    'kernel': ['linear', 'rbf', 'sigmoid'],
    'gamma': ['scale', 'auto']
}

classifier = SVC()
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
grid_search = GridSearchCV(classifier, param_grid, cv=cv, scoring='accuracy')
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=SVC(),
#              param_grid={'C': [5, 6, 7, 8, 9], 'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'rbf', 'sigmoid']},
#              scoring='accuracy')

# %%
best_params = grid_search.best_params_ # Get the best parameters and estimator from the grid search
print(best_params)
best_classifier = grid_search.best_estimator_
# Out:
# {'C': 5, 'gamma': 'scale', 'kernel': 'rbf'}

# %%
best_classifier
# Out:
# SVC(C=5)

# %%
y_pred = best_classifier.predict(X_test) # Predict using the best classifier

# %%
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"Best Parameters: {best_params}")
print(f"Accuracy: {accuracy}")
print("Classification Report:")
print(report)

# classifier = SVC(C= 7, gamma= 'scale', kernel='rbf')
# classifier.fit(X_train, y_train)

# y_pred = classifier.predict(X_test)
# accuracy = accuracy_score(y_test, y_pred)
# report = classification_report(y_test, y_pred)
# Out:
# Best Parameters: {'C': 5, 'gamma': 'scale', 'kernel': 'rbf'}
# Accuracy: 0.9130434782608695
# Classification Report:
#                           precision    recall  f1-score   support
#
#             Finance Team       0.97      0.93      0.95        42
# Product Development Team       0.89      0.96      0.92        49
#             Support Team       0.89      0.85      0.87        47
#
#                 accuracy                           0.91       138
#                macro avg       0.92      0.91      0.91       138
#             weighted avg       0.91      0.91      0.91       138

# %%
# single_sentence = "Where is the option of new user in Nurturev?" # Support Team
single_sentence = "The main page of Home app is not working. Make the corrections to rectify it."
single_sentence_encoded = use_model([single_sentence])
predicted_label = best_classifier.predict(single_sentence_encoded)
print("Predicted Label:", predicted_label[0])
# Out:
# Predicted Label: Product Development Team

# %%
import joblib  # Use joblib to save and load models
joblib.dump(best_classifier, 'best_svc_model.pkl') # Save the best_classifier to a file
# Out:
# ['best_svc_model.pkl']

# %%
# Load the saved model
import joblib  # Use joblib to save and load models
loaded_model = joblib.load('best_svc_model.pkl')

# Single Sentence Prediction for production
# single_sentence = "There is some issue in the Home app. It stops as soon as it opens." # Product Development Team
single_sentence = "What are the different notification functionalities supported in the webapp?" # Product Development Team
# My workflow is not reflecting the dashboard despite saving it. Can you please help me out? # Support
# Page taking too time to load # Support

single_sentence_encoded = list(use_model([single_sentence]))
predicted_label = loaded_model.predict(single_sentence_encoded)
print("Predicted Label:", predicted_label[0])

# %% [markdown]
# ### FEEDBACK based model correction.

# %%
import joblib
import numpy as np

def predict_and_retrain():
    global df
    print(len(df))
    
    model = joblib.load('best_svc_model2.pkl')
    module_url = "https://tfhub.dev/google/universal-sentence-encoder/4"
    use_model = hub.load(module_url)
    
    X = df['Request']
    y = df['Team']
    X_encoded = list(use_model(X))
    
    single_sentence = input("Please provide the sentence for prediction: ")
    single_sentence_encoded = list(use_model([single_sentence]))
    predicted_label = model.predict(single_sentence_encoded)[0]
    print("Predicted Label:", predicted_label)
    
    feedback = input(f"Was the predicted label '{predicted_label}' correct? (yes/no): ").strip().lower()
    
    if feedback == 'no':
        correct_label = input("Please provide the correct label: ").strip()
        
        # Create a new DataFrame with the new data and concatenate it with the original df
        new_data = {'Request': [single_sentence], 'Team': [correct_label]}
        new_df = pd.DataFrame(new_data)
        df = pd.concat([df, new_df], ignore_index=True)
        
        # Combine the single feedback instance with the full original training data
        X_combined = np.vstack([single_sentence_encoded, np.array(X_encoded)])
        y_combined = [correct_label] + list(y)
        
        model.fit(X_combined, y_combined)  # Retrain the model with the combined data
        
        joblib.dump(model, 'best_svc_model2.pkl')
        print("Model has been updated and saved!")
    else:
        print("Thank you for the feedback!")

predict_and_retrain()
# Out:
# 1381
# Please provide the sentence for prediction: How should I structure the data model in my Netsuite application such that the payload that I get from the integration suites the use case of finance teams to conduct audit?
# Predicted Label: Support Team
# Was the predicted label 'Support Team' correct? (yes/no): no
# Please provide the correct label: Product Development Team
# Model has been updated and saved!

# %%
original_model = joblib.load('best_svc_model.pkl')
print("Original Model Support Vectors:", len(original_model.support_vectors_))

retrained_model = joblib.load('best_svc_model2.pkl')
print("Retrained Model Support Vectors:", len(retrained_model.support_vectors_))

# retrained_model2 = joblib.load('best_svc_model3.pkl')
# print("Retrained Model Support Vectors:", len(retrained_model2.support_vectors_))
# Out:
# Original Model Support Vectors: 706
# Retrained Model Support Vectors: 760

# %%
## Assuming that I have a feedback_dataframe which is saved on getting a "no" as feedback.
feedback_df = pd.DataFrame(columns=['Request','Team']) # This will be saved based on negative feedback.

import joblib
import tensorflow_hub as hub

def retrain_on_feedback(feedback_df):
    model = joblib.load('best_svc_model.pkl')
    module_url = "https://tfhub.dev/google/universal-sentence-encoder/4"
    use_model = hub.load(module_url)

    # Encode the sentences from feedback_df
    X_feedback_encoded = list(use_model(feedback_df['Request']))
    y_feedback = feedback_df['Team'].values

    # Retrain the model on the feedback data
    model.fit(X_feedback_encoded, y_feedback)

    # Save the retrained model back to 'best_svc_model.pkl'
    joblib.dump(model, 'best_svc_model.pkl')
    print("Model has been retrained and saved based on user feedback!")

# Assuming feedback_df is already loaded
retrain_on_feedback(feedback_df)

# Re-training in this procedure would reduce the cases of overfitting on the batch.

# %% [markdown]
# # DQN_classifier for Reinforcement Learning

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
import tensorflow_hub as hub
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

module_url = "https://tfhub.dev/google/universal-sentence-encoder/4"
use_model = hub.load(module_url)

# %%
X = df['Request']
y = df['Team']

X_encoded = list(use_model(X))
X_encoded = np.array(X_encoded)

le = LabelEncoder()
y_encoded = le.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(X_encoded, y_encoded, test_size=0.1, random_state=42)

# %%
class DQNClassifier:
    def __init__(self, input_dim, num_classes, gamma=0.95, alpha=0.01):
        self.input_dim = input_dim
        self.num_classes = num_classes
        self.model = self._build_model()
        self.gamma = gamma
        self.alpha = alpha

    def _build_model(self):
        model = Sequential()
        model.add(Dense(128, input_dim=self.input_dim, activation='relu'))
        model.add(Dense(64, activation='relu'))
        model.add(Dense(self.num_classes, activation='linear'))
        model.compile(optimizer=Adam(lr=0.001), loss='mse')
        return model

    def _compute_val_loss(self, X_val, y_val):
        val_loss = 0
        for i, state in enumerate(X_val):
            target = self.model.predict(np.array([state]))
            action = y_val[i]
            val_loss += target[0][action]
        return val_loss / len(X_val)

    def train(self, X_train, y_train, X_val, y_val, epochs=100, batch_size=16, patience=5):
        best_val_loss = float('inf')
        no_improvement_epochs = 0

        for epoch in range(epochs):
            for i, state in enumerate(X_train):
                target = self.model.predict(np.array([state]))

                # Q-learning component
                next_state_q_values = self.model.predict(np.array([state]))
                max_next_q_value = np.max(next_state_q_values)
                action = y_train[i]
                reward = 1
                updated_q_value = (1 - self.alpha) * target[0][action] + self.alpha * (reward + self.gamma * max_next_q_value)
                target[0][action] = updated_q_value
                self.model.fit(np.array([state]), target, epochs=1, verbose=0, batch_size=batch_size)

            # Early stopping based on validation loss
            val_loss = self._compute_val_loss(X_val, y_val)
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                no_improvement_epochs = 0
            else:
                no_improvement_epochs += 1

            if no_improvement_epochs >= patience:
                print(f"Early stopping at epoch {epoch}")
                break
                
    def predict(self, X):
        # Using the trained model to make predictions
        predicted_q_values = self.model.predict(X)
        # Return the action with the highest Q-value for each sample
        return np.argmax(predicted_q_values, axis=1)

# %%
# 1. Instantiate the DQNClassifier
dqn_classifier = DQNClassifier(input_dim=X_train.shape[1], num_classes=len(np.unique(y_encoded)))

# 2. Train the model
dqn_classifier.train(X_train, y_train, X_test, y_test, epochs=100, batch_size=16, patience=5)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# ...
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# Early stopping at epoch 14

# %%
# (Optionally) 3. Make predictions on new data
y_pred = dqn_classifier.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print("Classification Report:")
print(report)
# Out:
# 5/5 [==============================] - 0s 633us/step
# Accuracy: 0.5434782608695652
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.67      0.80        42
#            1       0.00      0.00      0.00        49
#            2       0.43      1.00      0.60        47
#
#     accuracy                           0.54       138
#    macro avg       0.48      0.56      0.47       138
# weighted avg       0.45      0.54      0.45       138
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Early Stopping for DQN-Classifier

# %%
# DQN Classifier with Early Stopping
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score, classification_report

class DQNClassifier:
    def __init__(self, input_dim, num_classes):
        self.input_dim = input_dim
        self.num_classes = num_classes
        self.model = self._build_model()

    def _build_model(self):
        model = Sequential()
        model.add(Dense(128, input_dim=self.input_dim, activation='relu'))
        model.add(Dense(16, activation='relu'))
        model.add(Dense(8, activation='relu'))
        model.add(Dense(self.num_classes, activation='linear'))
        model.compile(optimizer=Adam(lr=0.0001), loss='mse')
        return model

    def train(self, X_train, y_train, epochs=100, batch_size=16):
        early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
        self.model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test), callbacks=[early_stopping])

    def predict(self, X_test):
        return np.argmax(self.model.predict(X_test), axis=1)

# %%
dqn_classifier = DQNClassifier(input_dim=X_train.shape[1], num_classes=len(np.unique(y_encoded)))
dqn_classifier.train(X_train, y_train)

y_pred = dqn_classifier.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print("Classification Report:")
print(report)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/100
# 78/78 [==============================] - 0s 950us/step - loss: 0.6998 - val_loss: 0.2405
# Epoch 2/100
# 78/78 [==============================] - 0s 560us/step - loss: 0.1859 - val_loss: 0.1974
# Epoch 3/100
# 78/78 [==============================] - 0s 534us/step - loss: 0.1551 - val_loss: 0.1981
# Epoch 4/100
# 78/78 [==============================] - 0s 541us/step - loss: 0.1387 - val_loss: 0.1923
# Epoch 5/100
# 78/78 [==============================] - 0s 562us/step - loss: 0.1291 - val_loss: 0.1791
# Epoch 6/100
# 78/78 [==============================] - 0s 538us/step - loss: 0.1075 - val_loss: 0.1857
# Epoch 7/100
# 78/78 [==============================] - 0s 536us/step - loss: 0.0920 - val_loss: 0.1766
# Epoch 8/100
# 78/78 [==============================] - 0s 525us/step - loss: 0.0783 - val_loss: 0.1710
# Epoch 9/100
# 78/78 [==============================] - 0s 528us/step - loss: 0.0629 - val_loss: 0.1720
# Epoch 10/100
# 78/78 [==============================] - 0s 587us/step - loss: 0.0497 - val_loss: 0.1625
# Epoch 11/100
# 78/78 [==============================] - 0s 532us/step - loss: 0.0412 - val_loss: 0.1795
# Epoch 12/100
# 78/78 [==============================] - 0s 545us/step - loss: 0.0346 - val_loss: 0.1660
# Epoch 13/100
# 78/78 [==============================] - 0s 532us/step - loss: 0.0301 - val_loss: 0.1620
# Epoch 14/100
# 78/78 [==============================] - 0s 530us/step - loss: 0.0238 - val_loss: 0.1555
# Epoch 15/100
# 78/78 [==============================] - 0s 523us/step - loss: 0.0206 - val_loss: 0.1536
# Epoch 16/100
# 78/78 [==============================] - 0s 528us/step - loss: 0.0169 - val_loss: 0.1571
# Epoch 17/100
# 78/78 [==============================] - 0s 520us/step - loss: 0.0155 - val_loss: 0.1530
# Epoch 18/100
# 78/78 [==============================] - 0s 533us/step - loss: 0.0136 - val_loss: 0.1491
# Epoch 19/100
# 78/78 [==============================] - 0s 521us/step - loss: 0.0125 - val_loss: 0.1509
# Epoch 20/100
# 78/78 [==============================] - 0s 531us/step - loss: 0.0108 - val_loss: 0.1534
# Epoch 21/100
# 78/78 [==============================] - 0s 531us/step - loss: 0.0095 - val_loss: 0.1536
# Epoch 22/100
# 78/78 [==============================] - 0s 524us/step - loss: 0.0093 - val_loss: 0.1516
# Epoch 23/100
# 78/78 [==============================] - 0s 548us/step - loss: 0.0088 - val_loss: 0.1527
# 5/5 [==============================] - 0s 529us/step
# Accuracy: 0.2753623188405797
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.11      0.10      0.10        42
#            1       0.34      0.61      0.43        49
#            2       0.31      0.09      0.13        47
#
#     accuracy                           0.28       138
#    macro avg       0.25      0.26      0.22       138
# weighted avg       0.26      0.28      0.23       138

# %% [markdown]
# # Q-Learning in Reinforcement Learning

# %%
import numpy as np
import tensorflow as tf
import tensorflow_hub as hub
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

module_url = "https://tfhub.dev/google/universal-sentence-encoder/4"
use_model = hub.load(module_url)

X = df['Request']
y = df['Team']

# %%
X_encoded = list(use_model(X))
X_encoded = np.array(X_encoded)

# Encode labels
label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(y)

# 2. Split the data
X_train, X_test, y_train, y_test = train_test_split(X_encoded, encoded_labels, test_size=0.1, random_state=42)

# %%
# 3. Q-learning
n_states = len(X_train)
n_actions = 3  # 3 classes: Support Team, Finance Team, Product Development Team
alpha = 0.01  # learning rate
gamma = 0.5  # discount factor
epsilon = 0.2  # exploration rate

Q = np.zeros((n_states, n_actions))

def get_reward(true_label, predicted_label):
    return 1 if true_label == predicted_label else -1

# %%
for epoch in range(100):  # Number of training iterations
    for i, state in enumerate(X_train):
        if np.random.uniform(0, 1) < epsilon:
            action = np.random.choice(n_actions)  # Explore
        else:
            action = np.argmax(Q[i, :])  # Exploit

        reward = get_reward(y_train[i], action)
        Q[i, action] = Q[i, action] + alpha * (reward + gamma * np.max(Q[i, :]) - Q[i, action])

# 4. Evaluation
y_pred = []
for i, state in enumerate(X_test):
    action = np.argmax(Q[i, :])  # Exploit only during evaluation
    y_pred.append(action)

    if action == y_test[i]:
        correct_predictions += 1

# Classification report
labels = list(label_encoder.classes_)
report = classification_report(y_test, y_pred, target_names=labels)
print(f"Report : {report}")
# Out:
# Report :                           precision    recall  f1-score   support
#
#             Finance Team       0.33      0.38      0.36        42
# Product Development Team       0.35      0.31      0.33        49
#             Support Team       0.32      0.32      0.32        47
#
#                 accuracy                           0.33       138
#                macro avg       0.33      0.34      0.33       138
#             weighted avg       0.33      0.33      0.33       138

# %% [markdown]
# ## Early Stopping Criteria using Q-Learning

# %%
# 1. Split the data into train, validation, and test sets
X_trainval, X_test, y_trainval, y_test = train_test_split(X_encoded, encoded_labels, test_size=0.1, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_trainval, y_trainval, test_size=0.1, random_state=42)

n_states = len(X_train)
Q = np.zeros((n_states, n_actions))

patience = 10  # Number of epochs with no improvement after which training will be stopped.
best_val_loss = float('inf')
no_improvement_epochs = 0

for epoch in range(100):  # Maximum number of training iterations
    # Training
    for i, state in enumerate(X_train):
        if np.random.uniform(0, 1) < epsilon:
            action = np.random.choice(n_actions)
        else:
            action = np.argmax(Q[i, :])

        reward = get_reward(y_train[i], action)
        Q[i, action] = Q[i, action] + alpha * (reward + gamma * np.max(Q[i, :]) - Q[i, action])

    # Validation
    val_loss = 0
    for i, state in enumerate(X_val):
        action = np.argmax(Q[i, :])
        reward = get_reward(y_val[i], action)
        val_loss -= reward  # Negative reward is our loss

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        no_improvement_epochs = 0
    else:
        no_improvement_epochs += 1

    if no_improvement_epochs >= patience:
        print(f"Early stopping at epoch {epoch}")
        break
# Out:
# Early stopping at epoch 10

# %%
# ... Continue with the evaluation on X_test as before.

# 4. Evaluation
y_pred = []
for i, state in enumerate(X_test):
    action = np.argmax(Q[i, :])  # Exploit only during evaluation
    y_pred.append(action)

    if action == y_test[i]:
        correct_predictions += 1

# Classification report
labels = list(label_encoder.classes_)
report = classification_report(y_test, y_pred, target_names=labels)
print(f"Report : {report}")
# Out:
# Report :                           precision    recall  f1-score   support
#
#             Finance Team       0.24      0.26      0.25        42
# Product Development Team       0.20      0.20      0.20        49
#             Support Team       0.23      0.21      0.22        47
#
#                 accuracy                           0.22       138
#                macro avg       0.23      0.23      0.23       138
#             weighted avg       0.22      0.22      0.22       138

# %% [markdown]
# # RLHF - Reinforcement Learning Human Feedback

# %%
# saas_data = "/Users/abhishekkarmakar/Desktop/TAGGING/GPT based triaging.txt"

# requests, teams = [], []
# with open(saas_data, "r") as file:
#     lines = file.readlines()
#     for line in lines:
#         if line.startswith("Request:"):
#             request = line.split("Request:", 1)[1].strip()
#             request = request.strip('"') # This line removes the quotation marks
#             requests.append(request)
#         elif line.startswith("Team:"):
#             teams.append(line.split("Team:", 1)[1].strip())

# df = pd.DataFrame({
#     'Request': requests,
#     'Team': teams
# })


# tasks = [
#     {
#         "prompt":df['Request'][i],
#         "response":df['Team'][i]
#     }
#     for i in df.index
# ]

# # Saving the GPT-Traiging Data into json format
# with open('GPT based triaging.json', 'w') as f:
#     json.dump(tasks, f, indent=4)
# Out:
# [{'prompt': "I'm having trouble logging into my account.",
#   'response': 'Support Team'},
#  {'prompt': 'How do I upgrade my subscription plan?',
#   'response': 'Finance Team'}]

# %%
from torch.utils.tensorboard import SummaryWriter
from tqdm import tqdm
from torch.utils.data import Dataset, DataLoader
import torch
import torch.nn as nn
import pandas as pd
import json
from transformers import GPT2Tokenizer, GPT2LMHeadModel, GPT2Config
# Out:
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/bitsandbytes/cextension.py:34: UserWarning: The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers, 8-bit multiplication, and GPU quantization are unavailable.
#   warn("The installed version of bitsandbytes was compiled without GPU support. "
# 'NoneType' object has no attribute 'cadam32bit_grad_fp32'

# %%
class SFTModel(GPT2LMHeadModel):
    def __init__(self):
        configuration = GPT2Config.from_pretrained('gpt2')
        super().__init__(config=configuration)
        self.tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
        self.tokenizer.pad_token = self.tokenizer.eos_token
        self.to(torch.device("cpu"))

    def compute_loss(self, prompt, response):
        entire_text = prompt + response
        context_dict = self.tokenizer(entire_text, return_tensors="pt", padding=True, truncation=True, max_length=1024)
        
        input_ids = context_dict["input_ids"].to(self.device)
        attention_mask = context_dict["attention_mask"].to(self.device)
        labels = input_ids.clone()
        
        outputs = super().forward(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
        return outputs.loss
    
    def predict(self, sentence):
        with torch.no_grad():
            inputs = self.tokenizer(sentence, return_tensors="pt", truncation=True, max_length=1024, padding="max_length")
            input_ids = inputs["input_ids"].to(self.device)
            attention_mask = inputs["attention_mask"].to(self.device)

            # Generate outputs
            outputs = self(input_ids=input_ids, attention_mask=attention_mask)

            # Extract the logits for the last token in the sequence
            last_token_logits = outputs.logits[0, -1, :]

            # Softmax to get "pseudo-probabilities"
            pseudo_probs = torch.nn.functional.softmax(last_token_logits, dim=-1)
            print(pseudo_probs)
            print(len(pseudo_probs))

            # We will only consider the first three as valid class logits
            class_logits = pseudo_probs[:3] 

            # Find the argmax
            predicted_class_idx = torch.argmax(class_logits).item()

            # Decode or interpret the prediction based on your task
            predicted_response = self.decode_prediction(predicted_class_idx)

            return predicted_response

        
    def decode_prediction(self, idx):
        class_names = ["Support Team", "Finance Team", "Product Development Team"]

        # Check that the index is valid
        if 0 <= idx < len(class_names):
            return class_names[idx]
        else:
            raise ValueError(f"Unexpected class index: {idx}")

# %%
class SFTDataset(Dataset):
        """Supervised Fine-Tuning        ------->>>>            Returns: prompt: str
                                                                         response: str """        
        def __init__(self, file_path):
            with open(file_path) as f:
                self.data = json.load(f)
        def __len__(self):
            return len(self.data)
        def __getitem__(self, idx):
            return self.data[idx]["prompt"], self.data[idx]['response']

# %%
def train_and_save_SFT_model(epochs=10, data_file="GPT based triaging.json"):
    model = SFTModel()
    dataset = SFTDataset(file_path="GPT based triaging.json")
#     dataset = SFTDataset(data_file)
    dataloader = DataLoader(dataset, batch_size=8, shuffle=True)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5, betas=(0.9, 0.95))
    writer = SummaryWriter()
    batch_idx = 0
    
    for epoch in range(epochs):
        print(f"Epoch {epoch + 1}")
        for batch in tqdm(dataloader):
            prompt, response = batch
            loss = model.compute_loss(prompt, response)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            writer.add_scalar("SFT Model Loss/train", loss.item(), batch_idx)
            batch_idx += 1

    torch.save(model.state_dict(), "sft_model_params.pt")
    

# train_and_save_SFT_model()

# %%
from torch.utils.tensorboard import SummaryWriter
from tqdm import tqdm
from torch.utils.data import Dataset, DataLoader
import torch
import torch.nn as nn
import pandas as pd
import json
from transformers import GPT2Tokenizer, GPT2LMHeadModel, GPT2Config        

class GPT2ForClassification(GPT2LMHeadModel):
    def __init__(self, num_labels, tokenizer):
        config = GPT2Config.from_pretrained('gpt2')
        config.num_labels = num_labels
        super(GPT2ForClassification, self).__init__(config=config)

        self.num_labels = num_labels
        self.classifier = nn.Linear(self.config.n_embd, self.num_labels)

        # Resize token embeddings in case of added tokens
        self.resize_token_embeddings(len(tokenizer))

    def forward(self, input_ids, attention_mask=None, labels=None):
        outputs = super().forward(input_ids=input_ids, attention_mask=attention_mask)
        hidden_states = outputs[0]

        cls_output = hidden_states[:, 0, :]  
        logits = self.classifier(cls_output)

        loss = None
        if labels is not None:
            loss_fn = nn.CrossEntropyLoss()
            loss = loss_fn(logits, labels)

        return (loss, logits) if loss is not None else logits
    

class ClassificationDataset(Dataset):
    def __init__(self, data_file):
        with open(data_file, "r") as f:
            self.data = json.load(f)

        self.tokenizer = GPT2Tokenizer.from_pretrained("gpt2")

        # Add [CLS] token as a special token and resize model embeddings
        special_tokens_dict = {'cls_token': '[CLS]', 'pad_token': '[PAD]'}
        self.tokenizer.add_special_tokens(special_tokens_dict)
        
        self.label_map = {
            "Support Team": 0,
            "Finance Team": 1,
            "Product Development Team": 2
        }        

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        item = self.data[idx]
        text = "[CLS] " + item["prompt"]
        inputs = self.tokenizer.encode_plus(text, truncation=True, padding="max_length", max_length=1024, return_tensors="pt")
        
        label_id = self.label_map.get(item['response'], -1)
        if label_id == -1:
            raise ValueError(f"Invalid response: {item['response']}")
        
        return inputs["input_ids"].view(-1, 1024), inputs["attention_mask"].view(-1, 1024), torch.tensor(label_id)  
    
def train_classification_model(epochs=10):
    tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
    special_tokens_dict = {'cls_token': '[CLS]'}
    tokenizer.add_special_tokens(special_tokens_dict)

    model = GPT2ForClassification(num_labels=3, tokenizer=tokenizer).to(torch.device("cpu"))
    dataset = ClassificationDataset(data_file="GPT based triaging.json")
    tokenizer = dataset.tokenizer
    dataloader = DataLoader(dataset, batch_size=8, shuffle=True)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5, betas=(0.9, 0.95))

    for epoch in range(epochs):
        for batch in dataloader:
            input_ids, attention_mask, labels = batch
            loss, _ = model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()

    torch.save(model.state_dict(), "classification_model_params.pt")

train_classification_model()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 89
#      85             optimizer.zero_grad()
#      87     torch.save(model.state_dict(), "classification_model_params.pt")
# ---> 89 train_classification_model()
#
# Cell In[14], line 82, in train_classification_model(epochs)
#      80 for batch in dataloader:
#      81     input_ids, attention_mask, labels = batch
# ---> 82     loss, _ = model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
#      83     loss.backward()
#      84     optimizer.step()
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[14], line 23, in GPT2ForClassification.forward(self, input_ids, attention_mask, labels)
#      22 def forward(self, input_ids, attention_mask=None, labels=None):
# ---> 23     outputs = super().forward(input_ids=input_ids, attention_mask=attention_mask)
#      24     hidden_states = outputs[0]
#      26     cls_output = hidden_states[:, 0, :]
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/transformers/models/gpt2/modeling_gpt2.py:1046, in GPT2LMHeadModel.forward(self, input_ids, past_key_values, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1038 r"""
#    1039 labels (`torch.LongTensor` of shape `(batch_size, sequence_length)`, *optional*):
#    1040     Labels for language modeling. Note that the labels **are shifted** inside the model, i.e. you can set
#    1041     `labels = input_ids` Indices are selected in `[-100, 0, ..., config.vocab_size]` All labels set to `-100`
#    1042     are ignored (masked), the loss is only computed for labels in `[0, ..., config.vocab_size]`
#    1043 """
#    1044 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1046 transformer_outputs = self.transformer(
#    1047     input_ids,
#    1048     past_key_values=past_key_values,
#    1049     attention_mask=attention_mask,
#    1050     token_type_ids=token_type_ids,
#    1051     position_ids=position_ids,
#    1052     head_mask=head_mask,
#    1053     inputs_embeds=inputs_embeds,
#    1054     encoder_hidden_states=encoder_hidden_states,
#    1055     encoder_attention_mask=encoder_attention_mask,
#    1056     use_cache=use_cache,
#    1057     output_attentions=output_attentions,
#    1058     output_hidden_states=output_hidden_states,
#    1059     return_dict=return_dict,
#    1060 )
#    1061 hidden_states = transformer_outputs[0]
#    1063 # Set device for model parallelism
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/transformers/models/gpt2/modeling_gpt2.py:832, in GPT2Model.forward(self, input_ids, past_key_values, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, use_cache, output_attentions, output_hidden_states, return_dict)
#     829 head_mask = self.get_head_mask(head_mask, self.config.n_layer)
#     831 if inputs_embeds is None:
# --> 832     inputs_embeds = self.wte(input_ids)
#     833 position_embeds = self.wpe(position_ids)
#     834 hidden_states = inputs_embeds + position_embeds
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/torch/nn/modules/sparse.py:158, in Embedding.forward(self, input)
#     157 def forward(self, input: Tensor) -> Tensor:
# --> 158     return F.embedding(
#     159         input, self.weight, self.padding_idx, self.max_norm,
#     160         self.norm_type, self.scale_grad_by_freq, self.sparse)
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/torch/nn/functional.py:2199, in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2193     # Note [embedding_renorm set_grad_enabled]
#    2194     # XXX: equivalent to
#    2195     # with torch.no_grad():
#    2196     #   torch.embedding_renorm_
#    2197     # remove once script supports set_grad_enabled
#    2198     _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2199 return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#
# IndexError: index out of range in self

# %%
model_path = "sft_model_params.pt"  # adjust path if needed
model = SFTModel()
model.load_state_dict(torch.load(model_path))
model.to(torch.device("cpu"))
# Out:
# SFTModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50257, 768)
#     (wpe): Embedding(1024, 768)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (1): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (2): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (3): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (4): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (5): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (6): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (7): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (8): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (9): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (10): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (11): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=50257, bias=False)
# )

# %%
# sentence = "Where is the option of new user in Nurturev?"  # Support team
# sentence = "I can't access my account." # Support team
# sentence = "The main page of Home app is not working. Make the corrections to rectify it." # Product Development Team
sentence = "There is some issue in the Home app. It stops as soon as it opens." # Product Development Team
prediction = model.predict(sentence)
print("Predicted Response:", prediction)
# Out:
# tensor([2.8812e-07, 4.3842e-09, 4.3782e-09,  ..., 5.3221e-09, 2.8879e-09,
#         9.9974e-01])
# 50257
# Predicted Response: Support Team

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)  # you might want to adjust learning rate

def fine_tune_on_feedback(prompt, correct_response, epochs=1):
    # Convert your single example into a format suitable for DataLoader
    feedback_dataset = [{"prompt": prompt, "response": correct_response}]
    feedback_loader = DataLoader(feedback_dataset, batch_size=1, shuffle=True)

    model.train()  # Set the model to training mode
    for epoch in range(epochs):
        for data in feedback_loader:
            prompt, response = data["prompt"], data["response"]
            loss = model.compute_loss(prompt, response)  # directly use this as loss
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()

# Here you'd provide the correct feedback
correct_response = "Product Development Team"
if prediction != correct_response:
    fine_tune_on_feedback(sentence, correct_response)

# %%
sentence = "There is some issue in the Home app. It stops as soon as it opens." # Product Development Team
prediction = model.predict(sentence)
print("Predicted Response:", prediction)
# Out:
# tensor([5.6736e-07, 9.1751e-09, 7.9027e-09,  ..., 9.5870e-09, 7.6453e-09,
#         9.9951e-01])
# 50257
# Predicted Response: Support Team

# %% [markdown]
# ### Neural Network

# %%
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.metrics import Recall

# %%
encoder = LabelEncoder()
y_encoded = encoder.fit_transform(y)
y_encoded = to_categorical(y_encoded) # One-hot encode the integer labels
X_encoded = list(use_model(X))

X_train, X_test, y_train, y_test = train_test_split(X_encoded, y_encoded, test_size=0.1, random_state=42)

# %%
model = Sequential()
model.add(Dense(512, input_dim=512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.6))
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(y_train.shape[1], activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(np.array(X_train), np.array(y_train), epochs=15, batch_size=16, verbose=1)
loss, accuracy = model.evaluate(np.array(X_test), np.array(y_test), verbose=0)

print(f"Loss: {loss}")
print(f"Accuracy: {accuracy}")
# Out:
# Epoch 1/15
# 76/76 [==============================] - 0s 1ms/step - loss: 0.8903 - accuracy: 0.6650
# Epoch 2/15
# 76/76 [==============================] - 0s 1ms/step - loss: 0.5747 - accuracy: 0.7980
# Epoch 3/15
# 76/76 [==============================] - 0s 1ms/step - loss: 0.4459 - accuracy: 0.8362
# Epoch 4/15
# 76/76 [==============================] - 0s 1ms/step - loss: 0.4051 - accuracy: 0.8454
# Epoch 5/15
# 76/76 [==============================] - 0s 1ms/step - loss: 0.3626 - accuracy: 0.8570
# Epoch 6/15
# 76/76 [==============================] - 0s 1ms/step - loss: 0.3534 - accuracy: 0.8728
# Epoch 7/15
# 76/76 [==============================] - 0s 2ms/step - loss: 0.3477 - accuracy: 0.8803
# Epoch 8/15
# 76/76 [==============================] - 0s 1ms/step - loss: 0.3019 - accuracy: 0.8820
# Epoch 9/15
# 76/76 [==============================] - 0s 1ms/step - loss: 0.2867 - accuracy: 0.8919
# Epoch 10/15
# 76/76 [==============================] - 0s 1ms/step - loss: 0.2963 - accuracy: 0.8828
# Epoch 11/15
# 76/76 [==============================] - 0s 1ms/step - loss: 0.2675 - accuracy: 0.8953
# Epoch 12/15
# 76/76 [==============================] - 0s 1ms/step - loss: 0.2833 - accuracy: 0.8878
# Epoch 13/15
# 76/76 [==============================] - 0s 1ms/step - loss: 0.2491 - accuracy: 0.9086
# Epoch 14/15
# 76/76 [==============================] - 0s 1ms/step - loss: 0.2302 - accuracy: 0.9185
# Epoch 15/15
# 76/76 [==============================] - 0s 1ms/step - loss: 0.2096 - accuracy: 0.9393
# Loss: 0.4172076880931854
# Accuracy: 0.8731343150138855

# %%
# Make predictions
y_pred = model.predict(np.array(X_test))
y_pred_labels = np.argmax(y_pred, axis=1)
y_test_labels = np.argmax(y_test, axis=1)

# Generate classification report
report = classification_report(y_test_labels, y_pred_labels, target_names=encoder.classes_)
print("Classification Report:")
print(report)
# Out:
# 5/5 [==============================] - 0s 761us/step
# Classification Report:
#                           precision    recall  f1-score   support
#
#             Finance Team       0.95      0.93      0.94        44
# Product Development Team       0.90      0.85      0.88        55
#             Support Team       0.74      0.83      0.78        35
#
#                 accuracy                           0.87       134
#                macro avg       0.87      0.87      0.87       134
#             weighted avg       0.88      0.87      0.87       134

# %% [markdown]
# ## use the Roberta Method

# %%
from transformers import RobertaTokenizer, RobertaModel
import torch

# %%
tokenizer = RobertaTokenizer.from_pretrained("roberta-base")
model = RobertaModel.from_pretrained("roberta-base")
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
X = df['Request']
y = df['Team']

# %%
# Encode sentences using RoBERTa
X_encoded = []
for sentence in X:
    inputs = tokenizer(sentence, return_tensors="pt", padding="max_length", truncation=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
    sentence_embedding = outputs.last_hidden_state.mean(dim=1).squeeze().numpy()
    X_encoded.append(sentence_embedding)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.1, random_state=42)

# %%
param_grid = {
    'C': [5, 6, 7, 8, 9],
    'kernel': ['linear', 'rbf', 'sigmoid'],
    'gamma': ['scale', 'auto']
}

# %%
classifier = SVC()
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
grid_search = GridSearchCV(classifier, param_grid, cv=cv, scoring='accuracy')
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=SVC(),
#              param_grid={'C': [5, 6, 7, 8, 9], 'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'rbf', 'sigmoid']},
#              scoring='accuracy')

# %%
best_params = grid_search.best_params_
print(best_params)
best_classifier = grid_search.best_estimator_
# Out:
# {'C': 7, 'gamma': 'scale', 'kernel': 'linear'}

# %%
y_pred = best_classifier.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"Best Parameters: {best_params}")
print(f"Accuracy: {accuracy}")
print("Classification Report:")
print(report)
# Out:
# Best Parameters: {'C': 7, 'gamma': 'scale', 'kernel': 'linear'}
# Accuracy: 0.8656716417910447
# Classification Report:
#                           precision    recall  f1-score   support
#
#             Finance Team       0.98      0.93      0.95        44
# Product Development Team       0.88      0.84      0.86        55
#             Support Team       0.72      0.83      0.77        35
#
#                 accuracy                           0.87       134
#                macro avg       0.86      0.87      0.86       134
#             weighted avg       0.87      0.87      0.87       134
