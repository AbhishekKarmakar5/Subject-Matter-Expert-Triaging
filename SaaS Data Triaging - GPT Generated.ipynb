# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ### Prompt Used to generate SaaS Training Dataset:
#
# Can you help me generate a long list customer requests that come in for some Saas company that has to be triaged to different departments like product teams, support teams, finance teams etc. Could you make the requests or questions from customers as realistic as possible. Provide the answer in terms of the question asked and the team the request needs to be triaged to.

# %%
saas_data = "/Users/abhishekkarmakar/Desktop/TAGGING/GPT based triaging.txt"

# %%
requests, teams = [], []

with open(saas_data, "r") as file:
    lines = file.readlines()
    for line in lines:
        if line.startswith("Request:"):
            request = line.split("Request:", 1)[1].strip()
            request = request.strip('"') # This line removes the quotation marks
            requests.append(request)
        elif line.startswith("Team:"):
            teams.append(line.split("Team:", 1)[1].strip())

# %%
df = pd.DataFrame({
    'Request': requests,
    'Team': teams
})

df['Team'].value_counts()
# Out:
# Support Team                460
# Finance Team                459
# Product Development Team    458
# Sales Team                   17
# Training Team                 6
# Marketing Team                5
# Legal Team                    5
# Security Team                 4
# IT Operations Team            4
# Implementation Team           2
# Finance                       1
# Name: Team, dtype: int64

# %%
df = df[(df['Team'] == 'Support Team') | (df['Team'] == 'Finance Team') | (df['Team'] == 'Product Development Team')]

# %%
df['Team'].value_counts()
# Out:
# Support Team                460
# Finance Team                459
# Product Development Team    458
# Name: Team, dtype: int64

# %%
df.head(2)
# Out:
#                                        Request          Team
# 0  I'm having trouble logging into my account.  Support Team
# 1       How do I upgrade my subscription plan?  Finance Team

# %%
# !pip install tensorflow
# !pip install tensorflow_hub
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: tensorflow in /opt/homebrew/anaconda3/lib/python3.10/site-packages (2.14.0)
# Requirement already satisfied: tensorflow-macos==2.14.0 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: packaging in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.14.0->tensorflow) (22.0)
# Requirement already satisfied: ml-dtypes==0.2.0 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.14.0->tensorflow) (0.2.0)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.14.0->tensorflow) (23.5.26)
# Requirement already satisfied: six>=1.12.0 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.14.0->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.14.0->tensorflow) (1.60.0)
# Requirement already satisfied: setuptools in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.14.0->tensorflow) (65.6.3)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.14.0->tensorflow) (0.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.14.0->tensorflow) (0.34.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.14.0->tensorflow) (1.6.3)
# Requirement already satisfied: numpy>=1.23.5 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.14.0->tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.14.0->tensorflow) (3.3.0)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.14.0->tensorflow) (4.23.3)
# Requirement already satisfied: libclang>=13.0.0 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.14.0->tensorflow) (16.0.6)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.14.0->tensorflow) (0.2.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.14.0->tensorflow) (1.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.14.0->tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.14.0->tensorflow) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.14.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.14.0->tensorflow) (2.14.1)
# Requirement already satisfied: h5py>=2.9.0 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.14.0->tensorflow) (3.7.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.14.0->tensorflow) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (2.21.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (3.4.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (2.2.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (0.7.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (5.3.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (4.9)
# Requirement already satisfied: urllib3<2.0 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (1.26.14)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (3.2.2)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: tensorflow_hub in /opt/homebrew/anaconda3/lib/python3.10/site-packages (0.14.0)
# Requirement already satisfied: numpy>=1.12.0 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from tensorflow_hub) (1.23.5)
# Requirement already satisfied: protobuf>=3.19.6 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from tensorflow_hub) (4.23.3)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
import tensorflow_hub as hub

from sklearn.model_selection import GridSearchCV, train_test_split, StratifiedKFold

# %%
module_url = "https://tfhub.dev/google/universal-sentence-encoder/4"
use_model = hub.load(module_url)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[66], line 2
#       1 module_url = "https://www.kaggle.com/models/google/universal-sentence-encoder/frameworks/TensorFlow2/variations/universal-sentence-encoder/versions/2" # "https://tfhub.dev/google/universal-sentence-encoder/4"
# ----> 2 use_model = hub.load(module_url)
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/tensorflow_hub/module_v2.py:93, in load(handle, tags, options)
#      91 if not isinstance(handle, str):
#      92   raise ValueError("Expected a string, got %s" % handle)
# ---> 93 module_path = resolve(handle)
#      94 is_hub_module_v1 = tf.io.gfile.exists(
#      95     native_module.get_module_proto_path(module_path))
#      96 if tags is None and is_hub_module_v1:
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/tensorflow_hub/module_v2.py:48, in resolve(handle)
#      24 def resolve(handle):
#      25   """Resolves a module handle into a path.
#      26
#      27   This function works both for plain TF2 SavedModels and the legacy TF1 Hub
#    (...)
#      46     A string representing the Module path.
#      47   """
# ---> 48   return registry.resolver(handle)
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/tensorflow_hub/registry.py:49, in MultiImplRegister.__call__(self, *args, **kwargs)
#      47 for impl in reversed(self._impls):
#      48   if impl.is_supported(*args, **kwargs):
# ---> 49     return impl(*args, **kwargs)
#      50   else:
#      51     fails.append(type(impl).__name__)
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/tensorflow_hub/compressed_module_resolver.py:81, in HttpCompressedFileResolver.__call__(self, handle)
#      77   response = self._call_urlopen(request)
#      78   return resolver.DownloadManager(handle).download_and_uncompress(
#      79       response, tmp_dir)
# ---> 81 return resolver.atomic_download(handle, download, module_dir,
#      82                                 self._lock_file_timeout_sec())
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/tensorflow_hub/resolver.py:421, in atomic_download(handle, download_fn, module_dir, lock_file_timeout_sec)
#     419 logging.info("Downloading TF-Hub Module '%s'.", handle)
#     420 tf.compat.v1.gfile.MakeDirs(tmp_dir)
# --> 421 download_fn(handle, tmp_dir)
#     422 # Write module descriptor to capture information about which module was
#     423 # downloaded by whom and when. The file stored at the same level as a
#     424 # directory in order to keep the content of the 'model_dir' exactly as it
#    (...)
#     429 # module caching protocol and no code in the TF-Hub library reads its
#     430 # content.
#     431 _write_module_descriptor_file(handle, module_dir)
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/tensorflow_hub/compressed_module_resolver.py:78, in HttpCompressedFileResolver.__call__.<locals>.download(handle, tmp_dir)
#      75 request = urllib.request.Request(
#      76     self._append_compressed_format_query(handle))
#      77 response = self._call_urlopen(request)
# ---> 78 return resolver.DownloadManager(handle).download_and_uncompress(
#      79     response, tmp_dir)
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/tensorflow_hub/resolver.py:192, in DownloadManager.download_and_uncompress(self, fileobj, dst_path)
#     182 """Streams the content for the 'fileobj' and stores the result in dst_path.
#     183
#     184 Args:
#    (...)
#     189   ValueError: Unknown object encountered inside the TAR file.
#     190 """
#     191 try:
# --> 192   file_utils.extract_tarfile_to_destination(
#     193       fileobj, dst_path, log_function=self._log_progress)
#     194   total_size_str = tf_utils.bytes_to_readable_str(
#     195       self._total_bytes_downloaded, True)
#     196   self._print_download_progress_msg(
#     197       "Downloaded %s, Total size: %s" % (self._url, total_size_str),
#     198       flush=True)
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/tensorflow_hub/file_utils.py:52, in extract_tarfile_to_destination(fileobj, dst_path, log_function)
#      49 abs_target_path = merge_relative_path(dst_path, tarinfo.name)
#      51 if tarinfo.isfile():
# ---> 52   extract_file(tgz, tarinfo, abs_target_path, log_function=log_function)
#      53 elif tarinfo.isdir():
#      54   tf.compat.v1.gfile.MakeDirs(abs_target_path)
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/tensorflow_hub/file_utils.py:35, in extract_file(tgz, tarinfo, dst_path, buffer_size, log_function)
#      33 dst = tf.compat.v1.gfile.GFile(dst_path, "wb")
#      34 while 1:
# ---> 35   buf = src.read(buffer_size)
#      36   if not buf:
#      37     break
#
# File /opt/homebrew/anaconda3/lib/python3.10/tarfile.py:696, in _FileInFile.readinto(self, b)
#     695 def readinto(self, b):
# --> 696     buf = self.read(len(b))
#     697     b[:len(buf)] = buf
#     698     return len(buf)
#
# File /opt/homebrew/anaconda3/lib/python3.10/tarfile.py:685, in _FileInFile.read(self, size)
#     683 if data:
#     684     self.fileobj.seek(offset + (self.position - start))
# --> 685     b = self.fileobj.read(length)
#     686     if len(b) != length:
#     687         raise ReadError("unexpected end of data")
#
# File /opt/homebrew/anaconda3/lib/python3.10/tarfile.py:522, in _Stream.read(self, size)
#     520 """Return the next size number of bytes from the stream."""
#     521 assert size is not None
# --> 522 buf = self._read(size)
#     523 self.pos += len(buf)
#     524 return buf
#
# File /opt/homebrew/anaconda3/lib/python3.10/tarfile.py:540, in _Stream._read(self, size)
#     538     self.buf = b""
#     539 else:
# --> 540     buf = self.fileobj.read(self.bufsize)
#     541     if not buf:
#     542         break
#
# File /opt/homebrew/anaconda3/lib/python3.10/http/client.py:465, in HTTPResponse.read(self, amt)
#     462 if self.length is not None and amt > self.length:
#     463     # clip the read to the "end of response"
#     464     amt = self.length
# --> 465 s = self.fp.read(amt)
#     466 if not s and amt:
#     467     # Ideally, we would raise IncompleteRead if the content-length
#     468     # wasn't satisfied, but it might break compatibility.
#     469     self._close_conn()
#
# File /opt/homebrew/anaconda3/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File /opt/homebrew/anaconda3/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/homebrew/anaconda3/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
X = df['Request']
y = df['Team']

# %%
X_encoded = list(use_model(X))
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.1, random_state=42)

# %% [markdown]
# ### Faiss DB and KNN based

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)
X_train.iloc[2]
# Out:
# "We've identified a need for additional data visualization options within the software. Can you explore adding more chart types?"

# %%
from langchain.docstore.document import Document
documents = []

for index in range(len(X_train)):
    documents.append(Document(page_content=X_train.iloc[index], metadata={'source': y_train.iloc[index]}))
    
documents
# Out:
# [Document(page_content='Our organization needs a feature that enables users to track changes made to data records. Can you develop an audit trail feature for data history tracking?', metadata={'source': 'Product Development Team'}),
#  Document(page_content='I believe I was overcharged for my subscription. Please investigate.', metadata={'source': 'Finance Team'}),
#  Document(page_content="We've identified a need for additional data visualization options within the software. Can you explore adding more chart types?", metadata={'source': 'Product Development Team'}),
#  Document(page_content="We're considering upgrading to a higher-tier subscription. Can you provide insights into the additional features and benefits of the upgraded plan?", metadata={'source': 'Finance Team'}),
#  Document(page_content='Can I switch my subscription plan in the middle of the billing cycle?', metadata={'source': 'Finance Team'}),
#  Document(page_content='I accidentally canceled my subscription. How can I reactivate it?', metadata={'source': 'Finance Team'}),
#  Document(page_content="We're interested in exploring different payment methods, including wire transfers. Can you provide details on the process and requirements for wire transfers?", metadata={'source': 'Finance Team'}),
#  Document(page_content="The software's data import process doesn't handle complex data structures well. Can you enhance the data import capabilities to accommodate more diverse data?", metadata={'source': 'Product Development Team'}),
#  Document(page_content='Users are requesting enhanced data visualization options. Can you collaborate on adding interactive charts and graphs to enhance data representation?', metadata={'source': 'Product Development Team'}),
#  Document(page_content="We need help in customizing the platform's appearance to match our branding. Can you guide us through the process of applying custom branding?", metadata={'source': 'Support Team'}),
#  Document(page_content='Users are struggling with navigating the new feature updates. Can you collaborate with the Product Development Team to create feature walkthroughs?', metadata={'source': 'Support Team'}),
#  Document(page_content='We need assistance in improving the response time for email support. Can you collaborate on streamlining email response processes during peak hours?', metadata={'source': 'Support Team'}),
#  Document(page_content='Our team needs to generate reports that display cross-departmental performance metrics. Can you guide us in setting up customized cross-departmental reports?', metadata={'source': 'Product Development Team'}),
#  Document(page_content="We're experiencing an unexpected error message when users attempt to upload files. Can you diagnose the file upload error and provide a solution?", metadata={'source': 'Support Team'}),
#  Document(page_content='Our users are having trouble resetting their passwords. Can you provide assistance and troubleshoot the password reset process?', metadata={'source': 'Support Team'}),
#  Document(page_content='Our team needs assistance in reconciling the charges on our subscription. Can you provide an itemized breakdown of the subscription charges?', metadata={'source': 'Finance Team'}),
#  Document(page_content="The software's subscription renewal emails lack information about upcoming changes in plan features. Can you provide detailed explanations for feature updates?", metadata={'source': 'Finance Team'}),
#  Document(page_content="We're encountering issues in synchronizing data with our CRM, resulting in data inconsistencies. Can you provide troubleshooting steps for CRM data sync problems?", metadata={'source': 'Support Team'}),
#  Document(page_content="The software's documentation doesn't cover advanced integration scenarios with external APIs. Can you provide guidance on complex API integrations?", metadata={'source': 'Product Development Team'}),
#  Document(page_content="We're looking to implement custom branding options in the software, including logo placement and color themes. How can we customize the branding?", metadata={'source': 'Product Development Team'}),
#  Document(page_content='Users are experiencing difficulties while attempting to cancel their subscriptions. Can you provide instructions on how to properly cancel a subscription?', metadata={'source': 'Support Team'}),
#  Document(page_content='The software is not compatible with my browser. Can you make it work?', metadata={'source': 'Product Development Team'}),
#  Document(page_content='Our team needs a feature that allows users to create custom email templates for automated notifications. Can you develop an email template customization tool?', metadata={'source': 'Product Development Team'}),
#  Document(page_content="We're experiencing inconsistencies in data synchronization between our local database and the cloud-based software. Can you investigate and resolve the synchronization issues?", metadata={'source': 'Support Team'}),
#  Document(page_content="We're interested in integrating the software with our customer feedback system to collect user opinions. Can you provide guidance on integrating with feedback platforms?", metadata={'source': 'Product Development Team'}),
#  Document(page_content='Our team needs to create custom email templates for different types of communication. Can you assist in setting up these customizable email templates?', metadata={'source': 'Product Development Team'}),
#  Document(page_content='Our team needs to evaluate the financial impact of offering a limited-time discount. Can you work on a cost analysis and projected revenue assessment?', metadata={'source': 'Finance Team'}),
#  Document(page_content='We need assistance in creating customized invoices for specific client projects. Can you guide us on how to generate project-specific invoices?', metadata={'source': 'Support Team'}),
#  Document(page_content="We're interested in exploring options for flexible billing cycles, such as bi-annual subscriptions. Can you provide information on different billing cycle options?", metadata={'source': 'Finance Team'}),
#  Document(page_content='Users are requesting additional resources for troubleshooting complex issues. Can you collaborate on creating advanced troubleshooting guides?', metadata={'source': 'Support Team'}),
#  Document(page_content="We're interested in setting up custom user roles with specific permissions. Can you guide us on creating and managing custom user roles?", metadata={'source': 'Product Development Team'}),
#  Document(page_content="The software's email notifications are not arriving in a timely manner. Can you optimize the email delivery process for quicker notifications?", metadata={'source': 'Product Development Team'}),
#  Document(page_content='Our organization requires an invoice format that includes a breakdown of subscription charges by user count. Can you implement user-based invoice breakdowns?', metadata={'source': 'Finance Team'}),
#  Document(page_content='Our team needs to create automated alerts for specific events within the software. Can you assist in setting up event-based automated notifications?', metadata={'source': 'Product Development Team'}),
#  Document(page_content="The software's chat support is unavailable during our business hours. Can you extend the chat support hours to better align with our time zone?", metadata={'source': 'Support Team'}),
#  Document(page_content='Users are unsure how to export their data for analysis. Can you provide step-by-step instructions on using the data export functionality?', metadata={'source': 'Support Team'}),
#  Document(page_content="The software's data visualization tools lack support for custom color schemes. Can you enhance the data visualization options to include customizable colors?", metadata={'source': 'Product Development Team'}),
#  Document(page_content="The software's documentation lacks troubleshooting steps for configuration errors. Can you create detailed guides for troubleshooting configuration issues?", metadata={'source': 'Support Team'}),
#  Document(page_content="The software's knowledge base lacks troubleshooting guides for common user issues. Can you create detailed troubleshooting resources?", metadata={'source': 'Support Team'}),
#  Document(page_content="We're receiving inquiries about platform updates and changes. Can you collaborate on a regular newsletter to keep users informed about updates?", metadata={'source': 'Support Team'}),
#  Document(page_content="The software's documentation lacks instructions on best practices for setting up security roles. Can you provide guidelines for security role configuration?", metadata={'source': 'Product Development Team'}),
#  Document(page_content="We've encountered an issue where the software crashes when using a specific browser version. Can you investigate and address this compatibility issue?", metadata={'source': 'Product Development Team'}),
#  Document(page_content='Our team is interested in offering more user training sessions. Can you collaborate on scheduling regular webinars for user education?', metadata={'source': 'Support Team'}),
#  Document(page_content="We've identified inconsistencies in the currency conversion rates applied to our subscription charges. Can you review and correct the currency conversion calculations?", metadata={'source': 'Finance Team'}),
#  Document(page_content="The software's mobile app is not available for our operating system. Can you provide information on the mobile app's compatibility and future releases?", metadata={'source': 'Product Development Team'}),
#  Document(page_content='The subscription renewal notifications lack information about any upcoming changes in contract terms. Can you provide details on upcoming changes affecting contracts?', metadata={'source': 'Finance Team'}),
#  Document(page_content='Our team needs guidance on handling refund requests for cancelled subscriptions. Can you explain the refund process and our policy?', metadata={'source': 'Finance Team'}),
#  Document(page_content="The software's reporting feature doesn't provide the level of granularity we need for financial analysis. Can you enhance the reporting options?", metadata={'source': 'Product Development Team'}),
#  Document(page_content="We're experiencing difficulties in generating custom reports that include data from multiple modules. Can you assist us in creating complex custom reports?", metadata={'source': 'Support Team'}),
#  Document(page_content="We're encountering issues with billing for added features after upgrading our subscription. Can you assist in resolving these feature-related charge discrepancies?", metadata={'source': 'Finance Team'}),
#  Document(page_content='Our organization is changing billing contacts. How can we update the billing contact information for our account?', metadata={'source': 'Finance Team'}),
#  Document(page_content="The software's chat support is not available during weekends. Can you extend chat support hours to ensure assistance is available on weekends?", metadata={'source': 'Support Team'}),
#  Document(page_content='Our team needs a feature to generate customized PDF reports with specific branding elements. Can you implement a PDF report customization tool?', metadata={'source': 'Product Development Team'}),
#  Document(page_content='Our team needs assistance in configuring API keys for integration with third-party services. Can you guide us through the process of setting up API keys?', metadata={'source': 'Support Team'}),
#  Document(page_content='Our organization requires an invoice format that breaks down charges by project phases. Can you implement project phase-specific charge breakdowns in the invoices?', metadata={'source': 'Finance Team'}),
#  Document(page_content="I can't find the invoice for my recent payment. Can you resend it?", metadata={'source': 'Finance Team'}),
#  Document(page_content='Users have questions about optimizing platform usage for their specific industry. Can you collaborate on creating industry-specific user guides?', metadata={'source': 'Support Team'}),
#  Document(page_content="We've noticed that the software's data imports result in duplicates within our database. Can you help us set up deduplication rules for imported data?", metadata={'source': 'Support Team'}),
#  Document(page_content="The software's data export feature doesn't offer integration with cloud storage platforms. Can you add the ability to export data directly to cloud storage?", metadata={'source': 'Product Development Team'}),
#  Document(page_content='Users are requesting an integration with a popular project management tool. Can you initiate development for a seamless integration with this tool?', metadata={'source': 'Product Development Team'}),
#  Document(page_content="The software's subscription renewal notifications lack information about upcoming changes in plan features. Can you provide clear explanations for upcoming feature enhancements?", metadata={'source': 'Finance Team'}),
#  Document(page_content='Our team is interested in exploring multi-currency billing options. Can you provide details on configuring and managing multi-currency billing?', metadata={'source': 'Finance Team'}),
#  Document(page_content="We're interested in exploring options for multi-year prepayment plans. Can you provide information on setting up multi-year prepayment and its benefits?", metadata={'source': 'Finance Team'}),
#  Document(page_content='Can I get a discount for subscribing to multiple licenses for our team?', metadata={'source': 'Finance Team'}),
#  Document(page_content='How do I transfer my subscription to a different user within our organization?', metadata={'source': 'Finance Team'}),
#  Document(page_content='Users have reported confusion regarding subscription plans and billing. Can you work on creating a user-friendly subscription plan comparison chart?', metadata={'source': 'Support Team'}),
#  Document(page_content='We need assistance in understanding how different subscription plans affect our billing cycle. Can you explain the impact of plan changes on our invoices?', metadata={'source': 'Support Team'}),
#  Document(page_content="We're looking to customize the software's invoices to include our company logo and branding. How can we set up custom invoice templates?", metadata={'source': 'Finance Team'}),
#  Document(page_content="We need to customize the software's dashboard to showcase different metrics for different departments. How can we personalize dashboards?", metadata={'source': 'Product Development Team'}),
#  Document(page_content="The software's chat support responses lack relevant knowledge about advanced features. Can you provide chat support agents with deeper product knowledge?", metadata={'source': 'Support Team'}),
#  Document(page_content='Users are requesting video tutorials for advanced platform features. Can you collaborate on creating detailed video guides for these features?', metadata={'source': 'Support Team'}),
#  Document(page_content='Users need assistance in understanding the new subscription plans and their pricing. Can you provide a breakdown of the features and costs?', metadata={'source': 'Support Team'}),
#  Document(page_content='Users are interested in multi-year subscription options. Can you collaborate on designing multi-year pricing plans and communicating the benefits?', metadata={'source': 'Finance Team'}),
#  Document(page_content='Our team needs guidance on handling inquiries related to GDPR compliance. Can you collaborate on creating standardized responses for GDPR-related queries?', metadata={'source': 'Support Team'}),
#  Document(page_content="We've identified an issue where certain browser versions display distorted layouts of the software. Can you troubleshoot and fix these layout issues?", metadata={'source': 'Product Development Team'}),
#  Document(page_content="The software's mobile app crashes upon opening. Can you investigate and fix it?", metadata={'source': 'Product Development Team'}),
#  Document(page_content="The software's data visualization tools lack support for creating waterfall charts. Can you enhance the data visualization options to include waterfall chart capabilities?", metadata={'source': 'Product Development Team'}),
#  Document(page_content='Our organization requires an invoice format that separates charges by project for internal cost tracking. Can you implement project-specific invoice breakdowns?', metadata={'source': 'Finance Team'}),
#  Document(page_content='Our organization requires a detailed breakdown of taxes and fees on our subscription invoice for compliance purposes. Can you provide a tax breakdown?', metadata={'source': 'Finance Team'}),
#  Document(page_content='Our team requires assistance in understanding how usage-based charges are calculated for specific features. Can you explain the calculation process?', metadata={'source': 'Finance Team'}),
#  Document(page_content='How can I export my customer data for analysis in a spreadsheet program?', metadata={'source': 'Support Team'}),
#  Document(page_content="We've identified discrepancies in the payment records on our account. Can you review and reconcile the payment discrepancies on our billing history?", metadata={'source': 'Finance Team'}),
#  Document(page_content='Users have inquired about flexible billing cycles. Can you explore options for offering quarterly billing cycles to accommodate user preferences?', metadata={'source': 'Finance Team'}),
#  Document(page_content='Our team needs clarification on how subscription charges are calculated when downgrading with custom features. Can you explain the calculation for downgraded plans?', metadata={'source': 'Finance Team'}),
#  Document(page_content='We have several team members who are unable to log into the software despite using correct credentials. Can you troubleshoot this?', metadata={'source': 'Support Team'}),
#  Document(page_content='Our organization is considering a significant expansion, and we need to evaluate scalability options for the software. Can you provide information on scalability?', metadata={'source': 'Product Development Team'}),
#  Document(page_content="We're encountering issues with emails sent from the platform being flagged as spam. Can you assist in optimizing email deliverability?", metadata={'source': 'Support Team'}),
#  Document(page_content="We've identified discrepancies between data displayed on the software and our external analytics platform. Can you help us troubleshoot these discrepancies?", metadata={'source': 'Support Team'}),
#  Document(page_content="We're interested in adjusting our subscription plan to add new users mid-billing cycle. Can you guide us on modifying the subscription and prorating the charges?", metadata={'source': 'Finance Team'}),
#  Document(page_content="We're experiencing discrepancies between data in the software and our external database. Can you help identify and resolve data synchronization issues?", metadata={'source': 'Support Team'}),
#  Document(page_content='Our team needs to import historical data from our previous software into the new system. Can you guide us through the data migration process?', metadata={'source': 'Support Team'}),
#  Document(page_content="We're interested in exploring options for setting up a trial period for a specific feature. Can you provide guidance on configuring trial periods and associated charges?", metadata={'source': 'Finance Team'}),
#  Document(page_content='I have a billing discrepancy. Can you help resolve it?', metadata={'source': 'Finance Team'}),
#  Document(page_content="I'm having difficulty in exporting data in a specific format that aligns with our reporting requirements. Can you provide guidance on custom exports?", metadata={'source': 'Support Team'}),
#  Document(page_content='The subscription renewal emails lack information about any upcoming changes in contract terms. Can you provide details on upcoming changes in contractual terms?', metadata={'source': 'Finance Team'}),
#  Document(page_content="We're interested in implementing a search auto-suggestion feature to help users find content faster. Can you develop and integrate this search enhancement?", metadata={'source': 'Product Development Team'}),
#  Document(page_content="Our team would like to customize the appearance of the software's forms to align with our brand identity. How can we customize form designs?", metadata={'source': 'Product Development Team'}),
#  Document(page_content='We need help setting up user permissions and access controls. Can you guide us through the process of configuring role-based access for our team?', metadata={'source': 'Support Team'}),
#  Document(page_content="The analytics dashboard is not updating in real-time. What's wrong?", metadata={'source': 'Product Development Team'}),
#  Document(page_content='Users have suggested a feature for real-time collaboration on documents. Can you collaborate on creating a collaborative document editing tool?', metadata={'source': 'Product Development Team'}),
#  Document(page_content="We'd like to set up custom billing cycles for different client projects. Is there flexibility in the billing scheduling?", metadata={'source': 'Finance Team'}),
#  Document(page_content='Our organization requires customized invoice templates with our branding and payment details. Can you implement invoice customization options?', metadata={'source': 'Finance Team'}),
#  Document(page_content="We're facing difficulties in connecting our software instance to a third-party analytics tool. Can you provide guidance on setting up the integration?", metadata={'source': 'Support Team'}),
#  Document(page_content='Our organization requires data encryption for sensitive information within the software. Can you ensure end-to-end encryption?', metadata={'source': 'Product Development Team'}),
#  Document(page_content="We're interested in integrating the software with our marketing automation platform. Can you provide guidance on integrating with marketing automation systems?", metadata={'source': 'Product Development Team'}),
#  Document(page_content='Our team would like to set up custom automated workflows based on certain triggers within the software. Is this possible?', metadata={'source': 'Product Development Team'}),
#  Document(page_content="The software's API seems to be slow when we retrieve large datasets. Can you optimize the API's performance for data retrieval?", metadata={'source': 'Product Development Team'}),
#  Document(page_content='Our team needs assistance in optimizing the invoicing process for large enterprise clients. Can you collaborate on improving the enterprise invoicing workflow?', metadata={'source': 'Finance Team'}),
#  Document(page_content="We're interested in integrating the software with our customer satisfaction survey platform. Can you provide documentation on integrating with survey tools?", metadata={'source': 'Product Development Team'}),
#  Document(page_content="I'm unable to upload files to the cloud storage. Please help!", metadata={'source': 'Support Team'}),
#  Document(page_content='Our team needs assistance in setting up API authentication for third-party integrations. Can you provide step-by-step instructions for API authentication?', metadata={'source': 'Support Team'}),
#  Document(page_content='Our team needs to set up automated data backups to ensure data continuity. How can we configure automated data backups?', metadata={'source': 'Support Team'}),
#  Document(page_content='Our team needs assistance in understanding how charges are calculated when adding new features to our existing subscription. Can you explain the charge calculation process?', metadata={'source': 'Finance Team'}),
#  Document(page_content='Our organization needs assistance in reconciling subscription charges with the usage metrics displayed on our account dashboard. Can you guide us through this reconciliation process?', metadata={'source': 'Finance Team'}),
#  Document(page_content="The software's documentation doesn't cover troubleshooting steps for common errors. Can you provide troubleshooting guides for these errors?", metadata={'source': 'Support Team'}),
#  Document(page_content="The software's mobile app is not displaying certain data points correctly. Can you address this display issue on the mobile interface?", metadata={'source': 'Product Development Team'}),
#  Document(page_content='Our organization needs assistance in understanding the breakdown of charges on our monthly subscription invoice. Can you provide a detailed explanation of the charges?', metadata={'source': 'Finance Team'}),
#  Document(page_content="The software's mobile app is not providing notifications as expected. Can you help troubleshoot and restore proper notification functionality?", metadata={'source': 'Product Development Team'}),
#  Document(page_content='Our organization requires an invoice format that includes detailed usage metrics alongside charges for transparent cost analysis. Can you implement usage metric inclusion in the invoice?', metadata={'source': 'Finance Team'}),
#  Document(page_content='The subscription renewal emails lack information about upcoming changes in pricing and features. Can you provide clear explanations for both pricing adjustments and feature updates?', metadata={'source': 'Finance Team'}),
#  Document(page_content='I need a copy of my invoice for tax purposes.', metadata={'source': 'Finance Team'}),
#  Document(page_content='I need a breakdown of the taxes applied to our subscription charges for accounting purposes. Can you provide that?', metadata={'source': 'Finance Team'}),
#  Document(page_content="We're encountering difficulties in setting up automated email notifications for specific events. Can you provide step-by-step instructions for configuring these notifications?", metadata={'source': 'Support Team'}),
#  Document(page_content='Users are having trouble resetting their passwords. Can you provide instructions on the password reset process and troubleshoot any issues?', metadata={'source': 'Support Team'}),
#  Document(page_content="We're interested in adjusting our subscription plan's billing date to match our fiscal calendar. Can you guide us on changing the billing cycle date?", metadata={'source': 'Finance Team'}),
#  Document(page_content="The software's user interface lacks consistency across different modules. Can you work on standardizing the user interface design for a cohesive look?", metadata={'source': 'Product Development Team'}),
#  Document(page_content='Users are requesting flexible billing cycles based on usage. Can you collaborate on implementing usage-based billing options for different subscription tiers?', metadata={'source': 'Finance Team'}),
#  Document(page_content="The software's reporting module doesn't offer a specific data filter that we require. Can you guide us on creating custom data filters for reporting?", metadata={'source': 'Product Development Team'}),
#  Document(page_content="The software's data visualization tools lack support for creating combination charts. Can you enhance the data visualization options to include combination chart capabilities?", metadata={'source': 'Product Development Team'}),
#  Document(page_content="We've noticed that the software's user interface is not fully accessible for users with disabilities. Can you prioritize accessibility improvements?", metadata={'source': 'Product Development Team'}),
#  Document(page_content="The software's user interface could benefit from better color contrast for improved accessibility. Can you enhance the color scheme for better readability?", metadata={'source': 'Product Development Team'}),
#  Document(page_content="The software's documentation lacks troubleshooting steps for data import failures. Can you create comprehensive guides for resolving data import issues?", metadata={'source': 'Support Team'}),
#  Document(page_content="The software's integration with our help desk system is not functioning correctly. Can you troubleshoot and fix the integration issues?", metadata={'source': 'Support Team'}),
#  Document(page_content="The software's chat support often provides solutions without acknowledging the context of our issue. Can you ensure that chat support agents understand the context before offering solutions?", metadata={'source': 'Support Team'}),
#  Document(page_content='Our organization requires an invoice format that displays charges categorized by project or department codes. Can you implement project or department code categorization in the invoice?', metadata={'source': 'Finance Team'}),
#  Document(page_content="Our users are reporting slow response times when using the application. Can you investigate and provide recommendations to improve the application's performance?", metadata={'source': 'Support Team'}),
#  Document(page_content='Our organization requires a breakdown of taxes and fees on our subscription invoice for accurate financial reporting. Can you provide an itemized invoice?', metadata={'source': 'Finance Team'}),
#  Document(page_content="We're facing difficulties with user account recovery. Can you provide step-by-step instructions for users to recover their accounts?", metadata={'source': 'Support Team'}),
#  Document(page_content='Our organization needs to change the primary contact associated with our subscription. How can we update the primary contact information?', metadata={'source': 'Support Team'}),
#  Document(page_content="We're interested in exploring flexible billing options, such as monthly and yearly plans. Can you provide details on setting up flexible billing?", metadata={'source': 'Finance Team'}),
#  Document(page_content='Our subscription renewal date coincides with our annual budget approval process. Can we change the renewal date to better align with our financial calendar?', metadata={'source': 'Finance Team'}),
#  Document(page_content="We're interested in exploring options to integrate the software with our customer feedback collection tool. Can you provide integration guidance?", metadata={'source': 'Support Team'}),
#  Document(page_content='Our team needs assistance in understanding the breakdown of taxes and fees on our subscription invoice. Can you provide clarification on the invoice charges?', metadata={'source': 'Finance Team'}),
#  Document(page_content="We're interested in exploring options for offering discounts to nonprofit organizations. Can you guide us on setting up nonprofit-specific pricing?", metadata={'source': 'Finance Team'}),
#  Document(page_content='We need assistance in creating a comprehensive troubleshooting guide for common technical issues. Can you collaborate on compiling a detailed troubleshooting resource?', metadata={'source': 'Support Team'}),
#  Document(page_content="The software's live chat support is not available during our business hours. Can you extend the live chat support hours to better accommodate us?", metadata={'source': 'Support Team'}),
#  Document(page_content="The software's user interface doesn't offer a dark mode option. Can you add a dark mode feature to enhance user experience, especially during late hours?", metadata={'source': 'Product Development Team'}),
#  Document(page_content="I'm having trouble canceling my subscription. Can you assist me?", metadata={'source': 'Finance Team'}),
#  Document(page_content="The software's subscription renewal process is not providing clear information about upcoming charges. Can you improve the renewal notification with detailed pricing?", metadata={'source': 'Finance Team'}),
#  Document(page_content="The software's documentation lacks troubleshooting steps for issues related to browser compatibility. Can you create a guide for troubleshooting browser-related issues?", metadata={'source': 'Support Team'}),
#  Document(page_content='Can you provide guidance on how to set up recurring invoices for clients?', metadata={'source': 'Support Team'}),
#  Document(page_content='Our team is encountering issues with data consistency across different modules of the software. Can you help us ensure consistent data integrity?', metadata={'source': 'Product Development Team'}),
#  Document(page_content="The software's API documentation lacks information on pagination and data retrieval limits. Can you provide guidance on handling large data sets via the API?", metadata={'source': 'Product Development Team'}),
#  Document(page_content="Our team needs assistance in configuring the software's auto-response messages for incoming support tickets. Can you guide us on setting up auto-responses?", metadata={'source': 'Support Team'}),
#  Document(page_content='Our team is interested in exploring API rate limiting and throttling options to ensure optimal API usage. Can you provide guidance on implementing these limits?', metadata={'source': 'Product Development Team'}),
#  Document(page_content='Our team needs assistance in understanding how charges are calculated when downgrading to a lower-tier subscription plan. Can you explain the charge calculation process for downgrades?', metadata={'source': 'Finance Team'}),
#  Document(page_content='Our team needs guidance on handling user inquiries related to data privacy. Can you provide a set of standardized responses for data privacy concerns?', metadata={'source': 'Support Team'}),
#  Document(page_content="We're experiencing billing discrepancies in our subscription charges. Can you review our account and rectify the billing issues?", metadata={'source': 'Finance Team'}),
#  Document(page_content="We're considering implementing referral rewards for our subscribers. Can you collaborate on designing a referral program with associated discounts?", metadata={'source': 'Finance Team'}),
#  Document(page_content='Our team needs to allocate software expenses to different cost centers. Can you provide customizable expense allocation options for our subscription?', metadata={'source': 'Finance Team'}),
#  Document(page_content='Our team needs clarification on how grace periods for payments are handled before subscription renewals. Can you explain the terms and process of grace periods?', metadata={'source': 'Finance Team'}),
#  Document(page_content='Our organization requires an invoice format that breaks down charges by department, project, and user category. Can you implement an invoice breakdown with these classifications?', metadata={'source': 'Finance Team'}),
#  Document(page_content='Users have inquired about the breakdown of taxes on their invoices. Can you collaborate on providing detailed explanations for tax components?', metadata={'source': 'Finance Team'}),
#  Document(page_content="I need assistance in creating custom workflows within the software to match our team's unique processes. Can you guide me?", metadata={'source': 'Support Team'}),
#  Document(page_content="We're experiencing issues with the software's multi-factor authentication (MFA) setup. Can you guide us through the process of configuring MFA?", metadata={'source': 'Support Team'}),
#  Document(page_content='Our organization is considering a pricing adjustment. Can you analyze market trends and assist in determining an appropriate pricing strategy?', metadata={'source': 'Finance Team'}),
#  Document(page_content="I'm encountering issues while trying to configure automated email notifications for specific triggers. Can you provide guidance on setting this up?", metadata={'source': 'Support Team'}),
#  Document(page_content="We're interested in exploring options for offering volume-based discounts to our enterprise clients. Can you guide us on setting up volume-based pricing?", metadata={'source': 'Finance Team'}),
#  Document(page_content="I'm trying to connect my software to a third-party tool via API, but I'm encountering authentication errors. How can I resolve this?", metadata={'source': 'Support Team'}),
#  Document(page_content='Our team needs clarification on how discounts and promotions are applied during subscription renewals. Can you explain the process of applying discounts to renewals?', metadata={'source': 'Finance Team'}),
#  Document(page_content="We've identified discrepancies in the currency conversion rates applied to our subscription charges. Can you review and rectify the currency conversion calculations?", metadata={'source': 'Finance Team'}),
#  Document(page_content='Users are experiencing errors when trying to upgrade or downgrade their subscription plans. Can you help diagnose these errors and provide solutions?', metadata={'source': 'Support Team'}),
#  Document(page_content="The software's data export feature is limiting the number of records we can export at once. Can you enhance the export capacity for larger datasets?", metadata={'source': 'Product Development Team'}),
#  Document(page_content='Our team is expanding, and we need to add new users to the software. How can we efficiently onboard multiple users?', metadata={'source': 'Support Team'}),
#  Document(page_content="The software's documentation doesn't cover advanced use cases. Can you provide advanced usage guides or tips for more complex scenarios?", metadata={'source': 'Product Development Team'}),
#  Document(page_content='Our team needs to export data in a specific format that aligns with our internal data processing. Can you enhance the export options to include this format?', metadata={'source': 'Product Development Team'}),
#  Document(page_content='Our team needs a feature that allows users to collaborate on documents in real time. Can you implement real-time collaboration functionality?', metadata={'source': 'Product Development Team'}),
#  Document(page_content='How do I cancel my subscription?', metadata={'source': 'Finance Team'}),
#  Document(page_content="I've noticed that the software's response time has decreased recently. Could you investigate the performance degradation?", metadata={'source': 'Product Development Team'}),
#  Document(page_content='Our team needs assistance in setting up conditional notifications based on user interactions. Can you provide guidance on creating conditional notification rules?', metadata={'source': 'Support Team'}),
#  Document(page_content='Our financial team requires invoices in a specific format for processing. Can we request custom invoice formatting?', metadata={'source': 'Finance Team'}),
#  Document(page_content='Our team needs to create custom templates for email communication within the software. Can you provide guidance on setting up custom email templates?', metadata={'source': 'Product Development Team'}),
#  Document(page_content='Our team needs assistance in restoring accidentally deleted data from the software. Can you guide us through the data recovery process?', metadata={'source': 'Support Team'}),
#  Document(page_content="We've identified the need for better integration with our existing accounting software. How can we enhance the data exchange between systems?", metadata={'source': 'Product Development Team'}),
#  Document(page_content="We're encountering difficulties in integrating the software with our CRM due to compatibility issues. Can you troubleshoot and address these integration compatibility problems?", metadata={'source': 'Support Team'}),
#  Document(page_content="The software's documentation lacks troubleshooting steps for database connection errors. Can you create detailed guides for resolving database connection issues?", metadata={'source': 'Support Team'}),
#  Document(page_content="We're interested in exploring options for custom invoicing dates to align with our financial reporting cycles. Can you provide information on customizable invoicing date options?", metadata={'source': 'Finance Team'}),
#  Document(page_content='Our organization is considering discontinuing certain features to optimize our subscription costs. Can you provide guidance on feature deactivation?', metadata={'source': 'Product Development Team'}),
#  Document(page_content="The software's data visualization tools lack support for creating custom annotations on charts. Can you enhance the data visualization capabilities to include annotation features?", metadata={'source': 'Product Development Team'}),
#  Document(page_content='Our team is facing challenges when trying to set up data sharing permissions across different departments. Can you guide us on managing data sharing?', metadata={'source': 'Support Team'}),
#  Document(page_content="We're encountering challenges in configuring the software's API to work with our CRM. Can you provide troubleshooting steps for API integration issues?", metadata={'source': 'Support Team'}),
#  Document(page_content='Our team needs a feature that allows users to create custom notifications based on specific triggers. Can you develop a customizable notification system?', metadata={'source': 'Product Development Team'}),
#  Document(page_content="Our team is struggling to configure the software's API rate limits for our application. Can you provide guidelines for optimal API usage?", metadata={'source': 'Product Development Team'}),
#  Document(page_content="The software's user interface is not intuitive. Can you improve the design?", metadata={'source': 'Product Development Team'}),
#  Document(page_content='Our organization needs assistance in understanding the breakdown of taxes applied to our subscription charges. Can you provide a detailed explanation of the tax components?', metadata={'source': 'Finance Team'}),
#  Document(page_content='Our team is interested in exploring voice-activated commands within the platform. Can you research and develop voice recognition functionality?', metadata={'source': 'Product Development Team'}),
#  Document(page_content="The software's chat support is not offering solutions to complex inquiries. Can you provide more training to the chat support team for handling advanced queries?", metadata={'source': 'Support Team'}),
#  Document(page_content="The software's user interface is not fully responsive on certain browsers. Can you optimize the software's compatibility for different web browsers?", metadata={'source': 'Product Development Team'}),
#  Document(page_content='Our organization requires a customized integration with our customer feedback platform. Can you provide guidance on configuring this custom integration?', metadata={'source': 'Support Team'}),
#  Document(page_content='Our team needs a feature to schedule automated data cleanups to maintain data accuracy. Can you develop a data cleanup scheduling tool?', metadata={'source': 'Product Development Team'}),
#  Document(page_content="I'm facing issues with setting up the software's notification system. Can you help me configure it correctly?", metadata={'source': 'Support Team'}),
#  Document(page_content='Users are requesting information about the tax components included in their subscription charges. Can you provide transparency on the tax calculations?', metadata={'source': 'Finance Team'}),
#  Document(page_content='Users are having trouble locating the user manual and documentation. Can you provide a direct link to the comprehensive user documentation?', metadata={'source': 'Support Team'}),
#  Document(page_content="The software's user interface needs a more streamlined navigation structure for easier module access. Can you optimize the UI navigation for improved user experience?", metadata={'source': 'Product Development Team'}),
#  Document(page_content='Users have requested a feature to enable real-time collaboration within documents. Can you consider implementing a collaborative editing feature?', metadata={'source': 'Product Development Team'}),
#  Document(page_content='We need to create custom approval workflows for different document types. Can you assist us in setting up these customizable approval processes?', metadata={'source': 'Product Development Team'}),
#  Document(page_content='Our organization needs to capture user feedback through surveys within the software. Can you develop an in-app survey feature for user feedback?', metadata={'source': 'Product Development Team'}),
#  Document(page_content="We're considering switching to a usage-based billing model. Can you provide information on how usage-based billing works and its benefits?", metadata={'source': 'Finance Team'}),
#  Document(page_content='Users are requesting information about available payment methods for subscription renewals. Can you provide an overview of the payment options?', metadata={'source': 'Finance Team'}),
#  Document(page_content="We're interested in adding user licenses to our subscription plan on a prorated basis. Can you provide guidance on how proration applies to adding user licenses?", metadata={'source': 'Finance Team'}),
#  Document(page_content="We're interested in exploring options for flexible payment terms to align with our financial cycles. Can you provide information on configuring payment terms?", metadata={'source': 'Finance Team'}),
#  Document(page_content='We need to configure automated reminders for upcoming project milestones within the software. Can you guide us on setting up these reminders?', metadata={'source': 'Product Development Team'}),
#  Document(page_content='The software is not sending email notifications for new tasks. Help!', metadata={'source': 'Product Development Team'}),
#  Document(page_content="The software's data analytics module lacks predictive analytics capabilities. Can you provide insights into potential enhancements for predictive analytics?", metadata={'source': 'Product Development Team'}),
#  Document(page_content="The software's API is returning unexpected error codes when integrating with our internal systems. Can you provide troubleshooting steps for API errors?", metadata={'source': 'Support Team'}),
#  Document(page_content="We've identified discrepancies in the billing amounts on our subscription. Can you investigate and rectify the discrepancies on our billing statement?", metadata={'source': 'Finance Team'}),
#  Document(page_content='Our team needs to export data in a specific format for reporting to regulatory authorities. Can you assist us in customizing data export formats?', metadata={'source': 'Support Team'}),
#  Document(page_content="I'd like to switch from monthly to quarterly billing for our subscription. How can we make this change?", metadata={'source': 'Finance Team'}),
#  Document(page_content='Our customers are interested in a mobile app version of our platform. Can you explore the development of a mobile app to enhance user accessibility?', metadata={'source': 'Product Development Team'}),
#  Document(page_content="We're interested in exploring options for quarterly billing cycles to match our financial reporting periods. Can you provide information on configuring quarterly billing cycles?", metadata={'source': 'Finance Team'}),
#  Document(page_content="We're interested in exploring options for customized invoicing cycles to match our budget cycles. Can you provide information on customizable invoicing frequencies?", metadata={'source': 'Finance Team'}),
#  Document(page_content="We've identified a discrepancy in the currency conversion rates applied to our subscription charges. Can you review and rectify the currency conversion calculations?", metadata={'source': 'Finance Team'}),
#  Document(page_content='Our organization requires customized invoice templates that adhere to specific tax regulations. Can you develop invoice templates that meet our tax requirements?', metadata={'source': 'Finance Team'}),
#  Document(page_content='Our organization is planning to integrate the software with our e-commerce platform for order processing. Can you provide integration guidelines?', metadata={'source': 'Support Team'}),
#  Document(page_content='The subscription renewal emails lack information about the duration of any ongoing promotions. Can you provide details on the duration of active promotional offers?', metadata={'source': 'Finance Team'}),
#  Document(page_content="The software's data visualization tools lack the ability to create customized charts. Can you provide guidance on creating custom visualizations?", metadata={'source': 'Product Development Team'}),
# ...
#  Document(page_content='What are the system requirements for using your software?', metadata={'source': 'Support Team'}),
#  Document(page_content="The software's data import process is time-consuming. Can you optimize the data import procedure to make it faster and more efficient?", metadata={'source': 'Product Development Team'}),
#  Document(page_content='I need help setting up my account and configuring the initial settings.', metadata={'source': 'Support Team'}),
#  Document(page_content="The software's subscription renewal notifications lack information about changes in plan terms. Can you provide clear explanations for upcoming plan adjustments?", metadata={'source': 'Finance Team'}),
#  Document(page_content="The software's subscription renewal notifications lack clear explanations of changes in plan features. Can you provide comprehensive explanations for upcoming feature changes?", metadata={'source': 'Finance Team'}),
#  Document(page_content='Users have inquiries about the exchange rates used for currency conversion in their invoices. Can you provide information on the exchange rate process?', metadata={'source': 'Finance Team'}),
#  Document(page_content="We're interested in exploring the software's API capabilities for building custom integrations with third-party tools. Can you provide API documentation and use cases?", metadata={'source': 'Product Development Team'}),
#  Document(page_content="We've identified inconsistencies in the currency conversion rates applied to our subscription charges. Can you review and rectify the currency conversion calculations?", metadata={'source': 'Finance Team'}),
#  Document(page_content='Our organization is planning a data migration to a new instance of the software. Can you provide guidance on the steps and best practices for data migration?', metadata={'source': 'Support Team'}),
#  Document(page_content="We're interested in integrating the software with our project management tool to streamline task tracking. Can you provide guidance on integrating with project management systems?", metadata={'source': 'Product Development Team'}),
#  Document(page_content="We're interested in exploring options for setting up quarterly prepayment plans. Can you provide information on configuring and managing quarterly prepayment?", metadata={'source': 'Finance Team'}),
#  Document(page_content='We need to generate a usage report that provides insights into which features our team members are utilizing the most. How can we access this data?', metadata={'source': 'Support Team'}),
#  Document(page_content='Our team needs clarification on how subscription charges are calculated during a plan downgrade. Can you explain the billing calculations during downgrades?', metadata={'source': 'Finance Team'}),
#  Document(page_content="The software's reporting module lacks a feature to schedule and automatically send reports to stakeholders. Can you guide us on setting up automated report delivery?", metadata={'source': 'Product Development Team'}),
#  Document(page_content="We've encountered an issue where the software is duplicating records. Can you assist in identifying and resolving this?", metadata={'source': 'Product Development Team'}),
#  Document(page_content='Our organization requires an invoice format that includes cost center codes for departmental allocation. Can you implement cost center code inclusion in the invoice format?', metadata={'source': 'Finance Team'}),
#  Document(page_content="The software's documentation lacks troubleshooting steps for API authentication errors. Can you create comprehensive guides for troubleshooting API authentication?", metadata={'source': 'Support Team'}),
#  Document(page_content='Our organization needs a feature to track and manage user feedback and feature requests directly within the software. Can you create a user feedback system?', metadata={'source': 'Product Development Team'}),
#  Document(page_content='Our organization needs a feature for users to collaborate on shared documents within the software. Can you implement a collaborative document editing feature?', metadata={'source': 'Product Development Team'}),
#  Document(page_content="The software's mobile app crashes when users attempt to perform a specific action. Can you investigate and resolve this action-triggered crash?", metadata={'source': 'Product Development Team'}),
#  Document(page_content='Our team is interested in offering extended support hours during peak usage times. Can you collaborate on implementing extended support coverage?', metadata={'source': 'Support Team'}),
#  Document(page_content='The user interface is confusing. Can you make it more intuitive?', metadata={'source': 'Product Development Team'}),
#  Document(page_content='I need help migrating my existing data from another software to yours.', metadata={'source': 'Support Team'}),
#  Document(page_content="We're encountering issues with data synchronization between the software and our inventory management system. Can you troubleshoot and provide solutions for real-time data sync?", metadata={'source': 'Support Team'}),
#  Document(page_content='The subscription invoices lack information on the breakdown of charges by department. Can you implement department-specific charge breakdowns in the invoices?', metadata={'source': 'Finance Team'}),
#  Document(page_content='Users are interested in a feature that provides real-time insights into customer behavior. Can you work on developing a dashboard for live user analytics?', metadata={'source': 'Product Development Team'}),
#  Document(page_content='We need to generate custom reports that provide insights into user engagement patterns within the software. How can we access this data?', metadata={'source': 'Support Team'}),
#  Document(page_content='The subscription renewal notifications lack information about upcoming promotions. Can you provide clarity on any active or upcoming promotions?', metadata={'source': 'Finance Team'}),
#  Document(page_content='Users have questions about VAT implications for international subscriptions. Can you collaborate on creating VAT-related FAQs and resources?', metadata={'source': 'Finance Team'}),
#  Document(page_content="We're interested in a feature that allows users to schedule automated reports for specific time intervals. Can you develop a report scheduling feature?", metadata={'source': 'Product Development Team'}),
#  Document(page_content='Our company is expanding globally, and we need to adjust the currency used for billing. How can we make this change?', metadata={'source': 'Finance Team'}),
#  Document(page_content="The software's payment processing is not accepting our credit card despite it being valid. Can you assist in resolving the payment issue?", metadata={'source': 'Finance Team'}),
#  Document(page_content='Our company is interested in adding a feature that enables users to collaborate on shared documents. How can we request the development of this feature?', metadata={'source': 'Product Development Team'}),
#  Document(page_content="We're encountering issues with billing for removed features after downgrading our subscription. Can you assist in resolving these feature-related charge discrepancies?", metadata={'source': 'Finance Team'}),
#  Document(page_content='Our users are encountering errors when attempting to update their payment methods. Can you assist in diagnosing and resolving these payment update issues?', metadata={'source': 'Support Team'}),
#  Document(page_content='Our team members are unsure about how to apply promotional discounts during the subscription process. Can you guide us on applying discounts correctly?', metadata={'source': 'Support Team'}),
#  Document(page_content='Our organization needs to migrate to a different payment gateway. Can you provide instructions on changing the payment gateway settings?', metadata={'source': 'Finance Team'}),
#  Document(page_content='Our team needs assistance in understanding how charges are calculated when downgrading to a lower-tier plan. Can you explain the charge calculation process for downgrades?', metadata={'source': 'Finance Team'}),
#  Document(page_content="We're encountering challenges when trying to set up integration with our marketing automation platform. Can you provide integration troubleshooting assistance?", metadata={'source': 'Support Team'}),
#  Document(page_content="The software's color scheme doesn't align with our brand identity. Can you provide options for customizing it?", metadata={'source': 'Product Development Team'}),
#  Document(page_content='How can I update my billing information?', metadata={'source': 'Finance Team'}),
#  Document(page_content='Our organization requires an invoice format that breaks down charges by project phases. Can you implement project phase-specific charge breakdowns in the invoices?', metadata={'source': 'Finance Team'}),
#  Document(page_content="The software's mobile app is not displaying certain content correctly on different devices. Can you troubleshoot and resolve these content display issues?", metadata={'source': 'Product Development Team'}),
#  Document(page_content="The software's chat support responses are too brief and don't fully address our inquiries. Can you improve the depth of responses provided in chat?", metadata={'source': 'Support Team'}),
#  Document(page_content='Users are seeking guidance on troubleshooting browser compatibility issues. Can you provide detailed steps for resolving browser-related problems?', metadata={'source': 'Support Team'}),
#  Document(page_content='Our team needs assistance in understanding how usage-based charges are calculated for specific features. Can you explain the calculation process for feature-based charges?', metadata={'source': 'Finance Team'}),
#  Document(page_content='We need help understanding how to customize our billing preferences, including invoice frequency and payment reminders. Can you guide us through these customization options?', metadata={'source': 'Support Team'}),
#  Document(page_content='Our team needs assistance in creating automated approval workflows with complex routing rules. Can you provide guidance on setting up advanced approval workflows?', metadata={'source': 'Support Team'}),
#  Document(page_content='Users are requesting better integration with external APIs. Can you explore the development of an API integration framework to streamline connections?', metadata={'source': 'Product Development Team'}),
#  Document(page_content="The software's email notifications are not reaching all team members. Can you investigate and ensure that all notifications are being delivered?", metadata={'source': 'Product Development Team'}),
#  Document(page_content="The software's subscription renewal notifications lack information about changes in plan features. Can you provide detailed explanations for upcoming feature changes?", metadata={'source': 'Finance Team'}),
#  Document(page_content="Our organization has specific branding guidelines, and we'd like to customize the software's appearance to match our branding. How can we achieve this?", metadata={'source': 'Product Development Team'}),
#  Document(page_content='I need an invoice for my recent payment.', metadata={'source': 'Finance Team'}),
#  Document(page_content="The software's dashboard widgets don't provide real-time data updates. Can you enhance the widgets to include automatic real-time updates?", metadata={'source': 'Product Development Team'}),
#  Document(page_content='Users are seeking guidance on using the new project management integration. Can you collaborate on creating user-friendly guides for this integration?', metadata={'source': 'Support Team'}),
#  Document(page_content='We need assistance in migrating data from an older version of your software to the latest version. Can you guide us through this process?', metadata={'source': 'Support Team'}),
#  Document(page_content='Is there a way to customize the email templates for notifications?', metadata={'source': 'Product Development Team'}),
#  Document(page_content='Our team needs assistance in setting up advanced filters for data visualization. Can you provide step-by-step instructions for creating and using filters?', metadata={'source': 'Support Team'}),
#  Document(page_content='The subscription invoices lack information on the breakdown of charges for each user role. Can you implement role-specific charge breakdowns in the invoices?', metadata={'source': 'Finance Team'}),
#  Document(page_content='Our team is looking for resources on best practices for integrating the software with our CRM. Can you provide integration guides and tips?', metadata={'source': 'Support Team'}),
#  Document(page_content='Our team is encountering problems with configuring single sign-on (SSO) for enhanced security. Can you assist us in setting up SSO properly?', metadata={'source': 'Support Team'}),
#  Document(page_content='Our team is interested in integrating with popular third-party payment gateways. Can you initiate API integrations with these payment providers?', metadata={'source': 'Product Development Team'}),
#  Document(page_content="We're encountering issues with the software's mobile app crashing when certain actions are performed. Can you investigate and fix these app crashes?", metadata={'source': 'Support Team'}),
#  Document(page_content='Users are requesting a dark mode option for the platform to reduce eye strain during extended usage. Can you implement a dark mode feature?', metadata={'source': 'Product Development Team'}),
#  Document(page_content="The software's data visualization tools lack advanced chart types. Can you add more advanced chart options for visualizing complex data?", metadata={'source': 'Product Development Team'}),
#  Document(page_content='Users are seeking details about the duration of active promotions affecting their subscription charges. Can you provide information on ongoing promotions?', metadata={'source': 'Finance Team'}),
#  Document(page_content='Users are asking about the exchange rates used for currency conversion in their invoices. Can you provide clarity on the currency conversion process?', metadata={'source': 'Finance Team'}),
#  Document(page_content="We're receiving requests for extended support hours. Can you evaluate the feasibility of offering extended support coverage for different time zones?", metadata={'source': 'Support Team'}),
#  Document(page_content="We've identified discrepancies in the currency conversion rates applied to our subscription charges. Can you review and rectify the currency conversion calculations?", metadata={'source': 'Finance Team'}),
#  Document(page_content='How can I export a detailed audit trail of user activities within the software?', metadata={'source': 'Support Team'}),
#  Document(page_content="The software's chat support often requires escalation to higher tiers, causing delays in issue resolution. Can you improve the first-contact resolution rate of chat support?", metadata={'source': 'Support Team'}),
#  Document(page_content="The software's chat support often closes our inquiries without resolving the issues. Can you ensure that chat support agents address all aspects of our concerns?", metadata={'source': 'Support Team'}),
#  Document(page_content='Our team is interested in exploring options for implementing tiered pricing based on usage volume. Can you guide us through the process of setting up tiered pricing?', metadata={'source': 'Finance Team'}),
#  Document(page_content="The software's data visualization tools lack the ability to display multiple data sets on a single chart. Can you enhance the visualizations for multi-data set comparison?", metadata={'source': 'Product Development Team'}),
#  Document(page_content="The software's documentation lacks troubleshooting steps for API rate limiting errors. Can you create detailed guides for resolving API rate limit issues?", metadata={'source': 'Support Team'}),
#  ...]

# %%
from langchain.docstore.document import Document
from sentence_transformers import SentenceTransformer
import faiss
import numpy as np

model = SentenceTransformer('all-MiniLM-L6-v2')

# Convert the content of each Document to embeddings
doc_embeddings = model.encode([doc.page_content for doc in documents])

# Convert embeddings to a format FAISS can work with (float32)
doc_embeddings = doc_embeddings.astype('float32')

# Create a FAISS index
index = faiss.IndexFlatL2(doc_embeddings.shape[1])
index.add(doc_embeddings)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/huggingface_hub/utils/_errors.py:270, in hf_raise_for_status(response, endpoint_name)
#     269 try:
# --> 270     response.raise_for_status()
#     271 except HTTPError as e:
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/api/models/sentence-transformers/universal-sentence-encoder
#
# The above exception was the direct cause of the following exception:
#
# RepositoryNotFoundError                   Traceback (most recent call last)
# Cell In[62], line 6
#       3 import faiss
#       4 import numpy as np
# ----> 6 model = SentenceTransformer('universal-sentence-encoder')
#       8 # Convert the content of each Document to embeddings
#       9 doc_embeddings = model.encode([doc.page_content for doc in documents])
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/sentence_transformers/SentenceTransformer.py:87, in SentenceTransformer.__init__(self, model_name_or_path, modules, device, cache_folder, use_auth_token)
#      83     model_path = os.path.join(cache_folder, model_name_or_path.replace("/", "_"))
#      85     if not os.path.exists(os.path.join(model_path, 'modules.json')):
#      86         # Download from hub with caching
# ---> 87         snapshot_download(model_name_or_path,
#      88                             cache_dir=cache_folder,
#      89                             library_name='sentence-transformers',
#      90                             library_version=__version__,
#      91                             ignore_files=['flax_model.msgpack', 'rust_model.ot', 'tf_model.h5'],
#      92                             use_auth_token=use_auth_token)
#      94 if os.path.exists(os.path.join(model_path, 'modules.json')):    #Load as SentenceTransformer model
#      95     modules = self._load_sbert_model(model_path)
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/sentence_transformers/util.py:442, in snapshot_download(repo_id, revision, cache_dir, library_name, library_version, user_agent, ignore_files, use_auth_token)
#     439 elif use_auth_token:
#     440     token = HfFolder.get_token()
# --> 442 model_info = _api.model_info(repo_id=repo_id, revision=revision, token=token)
#     444 storage_folder = os.path.join(
#     445     cache_dir, repo_id.replace("/", "_")
#     446 )
#     448 all_files = model_info.siblings
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:118, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     115 if check_use_auth_token:
#     116     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 118 return fn(*args, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/huggingface_hub/hf_api.py:1922, in HfApi.model_info(self, repo_id, revision, timeout, securityStatus, files_metadata, token)
#    1920     params["blobs"] = True
#    1921 r = get_session().get(path, headers=headers, timeout=timeout, params=params)
# -> 1922 hf_raise_for_status(r)
#    1923 data = r.json()
#    1924 return ModelInfo(**data)
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/huggingface_hub/utils/_errors.py:320, in hf_raise_for_status(response, endpoint_name)
#     306 elif error_code == "RepoNotFound" or response.status_code == 401:
#     307     # 401 is misleading as it is returned for:
#     308     #    - private and gated repos if user is not authenticated
#     309     #    - missing repos
#     310     # => for now, we process them as `RepoNotFound` anyway.
#     311     # See https://gist.github.com/Wauplin/46c27ad266b15998ce56a6603796f0b9
#     312     message = (
#     313         f"{response.status_code} Client Error."
#     314         + "\n\n"
#    (...)
#     318         " make sure you are authenticated."
#     319     )
# --> 320     raise RepositoryNotFoundError(message, response) from e
#     322 elif response.status_code == 400:
#     323     message = (
#     324         f"\n\nBad request for {endpoint_name} endpoint:" if endpoint_name is not None else "\n\nBad request:"
#     325     )
#
# RepositoryNotFoundError: 404 Client Error. (Request ID: Root=1-658de3b4-495dcd147b443391540b2779;eae622d9-17ad-45ec-9991-97f104446dce)
#
# Repository Not Found for url: https://huggingface.co/api/models/sentence-transformers/universal-sentence-encoder.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated.

# %%
def k_nearest_neighbor_search(input_sentence, k=10):
    # Convert the input sentence to embeddings
    sentence_embedding = model.encode([input_sentence]).astype('float32')

    # Perform k-NN search
    distances, indices = index.search(sentence_embedding, k)
    
    # Retrieve and return the metadata and distances of the k-nearest documents as a list of tuples
    # nearest_documents = [(documents[i].metadata, distances[0][j]) for j, i in enumerate(indices[0])] # This returns KNN documents along with distances
    
    # Find the minimum distance
    min_distance = np.min(distances[0])
    # Retrieve documents with the minimum distance
    nearest_documents = [documents[i].metadata.get('source') for j, i in enumerate(indices[0]) if distances[0][j] == min_distance] # This returns a list nearest distance document. 
    nearest_documents = list(set(nearest_documents))
    
    return nearest_documents

# %%
# Example usage
input_sentence = "I'm having trouble logging into my account"
nearest_documents_metadata = k_nearest_neighbor_search(input_sentence, k=10)

# Print the metadata of the nearest documents
for metadata in nearest_documents_metadata:
    print(metadata)
# Out:
# Support Team

# %%
from sklearn.metrics import classification_report

# Predict the class for each instance in X_test
y_pred = [k_nearest_neighbor_search(x) for x in X_test]

# Generate the classification report
print(classification_report(y_test, y_pred))
# Out:
#                           precision    recall  f1-score   support
#
#             Finance Team       0.95      0.90      0.93        42
# Product Development Team       0.76      0.84      0.80        49
#             Support Team       0.80      0.74      0.77        47
#
#                 accuracy                           0.83       138
#                macro avg       0.83      0.83      0.83       138
#             weighted avg       0.83      0.83      0.83       138

# %% [markdown]
# ### Support Vector Machine

# %%
param_grid = {
    'C': [5,6,7,8,9],
    'kernel': ['linear', 'rbf', 'sigmoid'],
    'gamma': ['scale', 'auto']
}

classifier = SVC()
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
grid_search = GridSearchCV(classifier, param_grid, cv=cv, scoring='accuracy')
grid_search.fit(X_train, y_train)

# %%
best_params = grid_search.best_params_ # Get the best parameters and estimator from the grid search
print(best_params)
best_classifier = grid_search.best_estimator_

# %%
best_classifier

# %%
y_pred = best_classifier.predict(X_test) # Predict using the best classifier

# %%
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"Best Parameters: {best_params}")
print(f"Accuracy: {accuracy}")
print("Classification Report:")
print(report)

# classifier = SVC(C= 7, gamma= 'scale', kernel='rbf')
# classifier.fit(X_train, y_train)

# y_pred = classifier.predict(X_test)
# accuracy = accuracy_score(y_test, y_pred)
# report = classification_report(y_test, y_pred)

# %%
# single_sentence = "Where is the option of new user in Nurturev?" # Support Team
single_sentence = "The main page of Home app is not working. Make the corrections to rectify it."
single_sentence_encoded = use_model([single_sentence])
predicted_label = best_classifier.predict(single_sentence_encoded)
print("Predicted Label:", predicted_label[0])

# %%
import joblib  # Use joblib to save and load models
joblib.dump(best_classifier, 'best_svc_model.pkl') # Save the best_classifier to a file

# %%
# Load the saved model
import joblib  # Use joblib to save and load models
loaded_model = joblib.load('best_svc_model.pkl')

# Single Sentence Prediction for production
# single_sentence = "There is some issue in the Home app. It stops as soon as it opens." # Product Development Team
single_sentence = "What are the different notification functionalities supported in the webapp?" # Product Development Team
# My workflow is not reflecting the dashboard despite saving it. Can you please help me out? # Support
# Page taking too time to load # Support

single_sentence_encoded = list(use_model([single_sentence]))
predicted_label = loaded_model.predict(single_sentence_encoded)
print("Predicted Label:", predicted_label[0])

# %% [markdown]
# ### FEEDBACK based model correction.

# %%
import joblib
import numpy as np

def predict_and_retrain():
    global df
    print(len(df))
    
    model = joblib.load('best_svc_model2.pkl')
    module_url = "https://tfhub.dev/google/universal-sentence-encoder/4"
    use_model = hub.load(module_url)
    
    X = df['Request']
    y = df['Team']
    X_encoded = list(use_model(X))
    
    single_sentence = input("Please provide the sentence for prediction: ")
    single_sentence_encoded = list(use_model([single_sentence]))
    predicted_label = model.predict(single_sentence_encoded)[0]
    print("Predicted Label:", predicted_label)
    
    feedback = input(f"Was the predicted label '{predicted_label}' correct? (yes/no): ").strip().lower()
    
    if feedback == 'no':
        correct_label = input("Please provide the correct label: ").strip()
        
        # Create a new DataFrame with the new data and concatenate it with the original df
        new_data = {'Request': [single_sentence], 'Team': [correct_label]}
        new_df = pd.DataFrame(new_data)
        df = pd.concat([df, new_df], ignore_index=True)
        
        # Combine the single feedback instance with the full original training data
        X_combined = np.vstack([single_sentence_encoded, np.array(X_encoded)])
        y_combined = [correct_label] + list(y)
        
        model.fit(X_combined, y_combined)  # Retrain the model with the combined data
        
        joblib.dump(model, 'best_svc_model2.pkl')
        print("Model has been updated and saved!")
    else:
        print("Thank you for the feedback!")

predict_and_retrain()

# %%
original_model = joblib.load('best_svc_model.pkl')
print("Original Model Support Vectors:", len(original_model.support_vectors_))

retrained_model = joblib.load('best_svc_model2.pkl')
print("Retrained Model Support Vectors:", len(retrained_model.support_vectors_))

# retrained_model2 = joblib.load('best_svc_model3.pkl')
# print("Retrained Model Support Vectors:", len(retrained_model2.support_vectors_))

# %%
## Assuming that I have a feedback_dataframe which is saved on getting a "no" as feedback.
feedback_df = pd.DataFrame(columns=['Request','Team']) # This will be saved based on negative feedback.

import joblib
import tensorflow_hub as hub

def retrain_on_feedback(feedback_df):
    model = joblib.load('best_svc_model.pkl')
    module_url = "https://tfhub.dev/google/universal-sentence-encoder/4"
    use_model = hub.load(module_url)

    # Encode the sentences from feedback_df
    X_feedback_encoded = list(use_model(feedback_df['Request']))
    y_feedback = feedback_df['Team'].values

    # Retrain the model on the feedback data
    model.fit(X_feedback_encoded, y_feedback)

    # Save the retrained model back to 'best_svc_model.pkl'
    joblib.dump(model, 'best_svc_model.pkl')
    print("Model has been retrained and saved based on user feedback!")

# Assuming feedback_df is already loaded
retrain_on_feedback(feedback_df)

# Re-training in this procedure would reduce the cases of overfitting on the batch.

# %% [markdown]
# # DQN_classifier for Reinforcement Learning

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
import tensorflow_hub as hub
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

module_url = "https://tfhub.dev/google/universal-sentence-encoder/4"
use_model = hub.load(module_url)

# %%
X = df['Request']
y = df['Team']

X_encoded = list(use_model(X))
X_encoded = np.array(X_encoded)

le = LabelEncoder()
y_encoded = le.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(X_encoded, y_encoded, test_size=0.1, random_state=42)

# %%
class DQNClassifier:
    def __init__(self, input_dim, num_classes, gamma=0.95, alpha=0.01):
        self.input_dim = input_dim
        self.num_classes = num_classes
        self.model = self._build_model()
        self.gamma = gamma
        self.alpha = alpha

    def _build_model(self):
        model = Sequential()
        model.add(Dense(128, input_dim=self.input_dim, activation='relu'))
        model.add(Dense(64, activation='relu'))
        model.add(Dense(self.num_classes, activation='linear'))
        model.compile(optimizer=Adam(lr=0.001), loss='mse')
        return model

    def _compute_val_loss(self, X_val, y_val):
        val_loss = 0
        for i, state in enumerate(X_val):
            target = self.model.predict(np.array([state]))
            action = y_val[i]
            val_loss += target[0][action]
        return val_loss / len(X_val)

    def train(self, X_train, y_train, X_val, y_val, epochs=100, batch_size=16, patience=5):
        best_val_loss = float('inf')
        no_improvement_epochs = 0

        for epoch in range(epochs):
            for i, state in enumerate(X_train):
                target = self.model.predict(np.array([state]))

                # Q-learning component
                next_state_q_values = self.model.predict(np.array([state]))
                max_next_q_value = np.max(next_state_q_values)
                action = y_train[i]
                reward = 1
                updated_q_value = (1 - self.alpha) * target[0][action] + self.alpha * (reward + self.gamma * max_next_q_value)
                target[0][action] = updated_q_value
                self.model.fit(np.array([state]), target, epochs=1, verbose=0, batch_size=batch_size)

            # Early stopping based on validation loss
            val_loss = self._compute_val_loss(X_val, y_val)
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                no_improvement_epochs = 0
            else:
                no_improvement_epochs += 1

            if no_improvement_epochs >= patience:
                print(f"Early stopping at epoch {epoch}")
                break
                
    def predict(self, X):
        # Using the trained model to make predictions
        predicted_q_values = self.model.predict(X)
        # Return the action with the highest Q-value for each sample
        return np.argmax(predicted_q_values, axis=1)

# %%
# 1. Instantiate the DQNClassifier
dqn_classifier = DQNClassifier(input_dim=X_train.shape[1], num_classes=len(np.unique(y_encoded)))

# 2. Train the model
dqn_classifier.train(X_train, y_train, X_test, y_test, epochs=100, batch_size=16, patience=5)

# %%
# (Optionally) 3. Make predictions on new data
y_pred = dqn_classifier.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print("Classification Report:")
print(report)

# %% [markdown]
# ## Early Stopping for DQN-Classifier

# %%
# DQN Classifier with Early Stopping
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score, classification_report

class DQNClassifier:
    def __init__(self, input_dim, num_classes):
        self.input_dim = input_dim
        self.num_classes = num_classes
        self.model = self._build_model()

    def _build_model(self):
        model = Sequential()
        model.add(Dense(128, input_dim=self.input_dim, activation='relu'))
        model.add(Dense(16, activation='relu'))
        model.add(Dense(8, activation='relu'))
        model.add(Dense(self.num_classes, activation='linear'))
        model.compile(optimizer=Adam(lr=0.0001), loss='mse')
        return model

    def train(self, X_train, y_train, epochs=100, batch_size=16):
        early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
        self.model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test), callbacks=[early_stopping])

    def predict(self, X_test):
        return np.argmax(self.model.predict(X_test), axis=1)

# %%
dqn_classifier = DQNClassifier(input_dim=X_train.shape[1], num_classes=len(np.unique(y_encoded)))
dqn_classifier.train(X_train, y_train)

y_pred = dqn_classifier.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print("Classification Report:")
print(report)

# %% [markdown]
# # Q-Learning in Reinforcement Learning

# %%
import numpy as np
import tensorflow as tf
import tensorflow_hub as hub
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

module_url = "https://tfhub.dev/google/universal-sentence-encoder/4"
use_model = hub.load(module_url)

X = df['Request']
y = df['Team']

# %%
X_encoded = list(use_model(X))
X_encoded = np.array(X_encoded)

# Encode labels
label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(y)

# 2. Split the data
X_train, X_test, y_train, y_test = train_test_split(X_encoded, encoded_labels, test_size=0.1, random_state=42)

# %%
# 3. Q-learning
n_states = len(X_train)
n_actions = 3  # 3 classes: Support Team, Finance Team, Product Development Team
alpha = 0.01  # learning rate
gamma = 0.5  # discount factor
epsilon = 0.2  # exploration rate

Q = np.zeros((n_states, n_actions))

def get_reward(true_label, predicted_label):
    return 1 if true_label == predicted_label else -1

# %%
for epoch in range(100):  # Number of training iterations
    for i, state in enumerate(X_train):
        if np.random.uniform(0, 1) < epsilon:
            action = np.random.choice(n_actions)  # Explore
        else:
            action = np.argmax(Q[i, :])  # Exploit

        reward = get_reward(y_train[i], action)
        Q[i, action] = Q[i, action] + alpha * (reward + gamma * np.max(Q[i, :]) - Q[i, action])

# 4. Evaluation
y_pred = []
for i, state in enumerate(X_test):
    action = np.argmax(Q[i, :])  # Exploit only during evaluation
    y_pred.append(action)

    if action == y_test[i]:
        correct_predictions += 1

# Classification report
labels = list(label_encoder.classes_)
report = classification_report(y_test, y_pred, target_names=labels)
print(f"Report : {report}")

# %% [markdown]
# ## Early Stopping Criteria using Q-Learning

# %%
# 1. Split the data into train, validation, and test sets
X_trainval, X_test, y_trainval, y_test = train_test_split(X_encoded, encoded_labels, test_size=0.1, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_trainval, y_trainval, test_size=0.1, random_state=42)

n_states = len(X_train)
Q = np.zeros((n_states, n_actions))

patience = 10  # Number of epochs with no improvement after which training will be stopped.
best_val_loss = float('inf')
no_improvement_epochs = 0

for epoch in range(100):  # Maximum number of training iterations
    # Training
    for i, state in enumerate(X_train):
        if np.random.uniform(0, 1) < epsilon:
            action = np.random.choice(n_actions)
        else:
            action = np.argmax(Q[i, :])

        reward = get_reward(y_train[i], action)
        Q[i, action] = Q[i, action] + alpha * (reward + gamma * np.max(Q[i, :]) - Q[i, action])

    # Validation
    val_loss = 0
    for i, state in enumerate(X_val):
        action = np.argmax(Q[i, :])
        reward = get_reward(y_val[i], action)
        val_loss -= reward  # Negative reward is our loss

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        no_improvement_epochs = 0
    else:
        no_improvement_epochs += 1

    if no_improvement_epochs >= patience:
        print(f"Early stopping at epoch {epoch}")
        break

# %%
# ... Continue with the evaluation on X_test as before.

# 4. Evaluation
y_pred = []
for i, state in enumerate(X_test):
    action = np.argmax(Q[i, :])  # Exploit only during evaluation
    y_pred.append(action)

    if action == y_test[i]:
        correct_predictions += 1

# Classification report
labels = list(label_encoder.classes_)
report = classification_report(y_test, y_pred, target_names=labels)
print(f"Report : {report}")

# %% [markdown]
# # RLHF - Reinforcement Learning Human Feedback

# %%
# saas_data = "/Users/abhishekkarmakar/Desktop/TAGGING/GPT based triaging.txt"

# requests, teams = [], []
# with open(saas_data, "r") as file:
#     lines = file.readlines()
#     for line in lines:
#         if line.startswith("Request:"):
#             request = line.split("Request:", 1)[1].strip()
#             request = request.strip('"') # This line removes the quotation marks
#             requests.append(request)
#         elif line.startswith("Team:"):
#             teams.append(line.split("Team:", 1)[1].strip())

# df = pd.DataFrame({
#     'Request': requests,
#     'Team': teams
# })


# tasks = [
#     {
#         "prompt":df['Request'][i],
#         "response":df['Team'][i]
#     }
#     for i in df.index
# ]

# # Saving the GPT-Traiging Data into json format
# with open('GPT based triaging.json', 'w') as f:
#     json.dump(tasks, f, indent=4)

# %%
from torch.utils.tensorboard import SummaryWriter
from tqdm import tqdm
from torch.utils.data import Dataset, DataLoader
import torch
import torch.nn as nn
import pandas as pd
import json
from transformers import GPT2Tokenizer, GPT2LMHeadModel, GPT2Config

# %%
class SFTModel(GPT2LMHeadModel):
    def __init__(self):
        configuration = GPT2Config.from_pretrained('gpt2')
        super().__init__(config=configuration)
        self.tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
        self.tokenizer.pad_token = self.tokenizer.eos_token
        self.to(torch.device("cpu"))

    def compute_loss(self, prompt, response):
        entire_text = prompt + response
        context_dict = self.tokenizer(entire_text, return_tensors="pt", padding=True, truncation=True, max_length=1024)
        
        input_ids = context_dict["input_ids"].to(self.device)
        attention_mask = context_dict["attention_mask"].to(self.device)
        labels = input_ids.clone()
        
        outputs = super().forward(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
        return outputs.loss
    
    def predict(self, sentence):
        with torch.no_grad():
            inputs = self.tokenizer(sentence, return_tensors="pt", truncation=True, max_length=1024, padding="max_length")
            input_ids = inputs["input_ids"].to(self.device)
            attention_mask = inputs["attention_mask"].to(self.device)

            # Generate outputs
            outputs = self(input_ids=input_ids, attention_mask=attention_mask)

            # Extract the logits for the last token in the sequence
            last_token_logits = outputs.logits[0, -1, :]

            # Softmax to get "pseudo-probabilities"
            pseudo_probs = torch.nn.functional.softmax(last_token_logits, dim=-1)
            print(pseudo_probs)
            print(len(pseudo_probs))

            # We will only consider the first three as valid class logits
            class_logits = pseudo_probs[:3] 

            # Find the argmax
            predicted_class_idx = torch.argmax(class_logits).item()

            # Decode or interpret the prediction based on your task
            predicted_response = self.decode_prediction(predicted_class_idx)

            return predicted_response

        
    def decode_prediction(self, idx):
        class_names = ["Support Team", "Finance Team", "Product Development Team"]

        # Check that the index is valid
        if 0 <= idx < len(class_names):
            return class_names[idx]
        else:
            raise ValueError(f"Unexpected class index: {idx}")

# %%
class SFTDataset(Dataset):
        """Supervised Fine-Tuning        ------->>>>            Returns: prompt: str
                                                                         response: str """        
        def __init__(self, file_path):
            with open(file_path) as f:
                self.data = json.load(f)
        def __len__(self):
            return len(self.data)
        def __getitem__(self, idx):
            return self.data[idx]["prompt"], self.data[idx]['response']

# %%
def train_and_save_SFT_model(epochs=10, data_file="GPT based triaging.json"):
    model = SFTModel()
    dataset = SFTDataset(file_path="GPT based triaging.json")
#     dataset = SFTDataset(data_file)
    dataloader = DataLoader(dataset, batch_size=8, shuffle=True)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5, betas=(0.9, 0.95))
    writer = SummaryWriter()
    batch_idx = 0
    
    for epoch in range(epochs):
        print(f"Epoch {epoch + 1}")
        for batch in tqdm(dataloader):
            prompt, response = batch
            loss = model.compute_loss(prompt, response)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            writer.add_scalar("SFT Model Loss/train", loss.item(), batch_idx)
            batch_idx += 1

    torch.save(model.state_dict(), "sft_model_params.pt")
    

# train_and_save_SFT_model()

# %%
from torch.utils.tensorboard import SummaryWriter
from tqdm import tqdm
from torch.utils.data import Dataset, DataLoader
import torch
import torch.nn as nn
import pandas as pd
import json
from transformers import GPT2Tokenizer, GPT2LMHeadModel, GPT2Config        

class GPT2ForClassification(GPT2LMHeadModel):
    def __init__(self, num_labels, tokenizer):
        config = GPT2Config.from_pretrained('gpt2')
        config.num_labels = num_labels
        super(GPT2ForClassification, self).__init__(config=config)

        self.num_labels = num_labels
        self.classifier = nn.Linear(self.config.n_embd, self.num_labels)

        # Resize token embeddings in case of added tokens
        self.resize_token_embeddings(len(tokenizer))

    def forward(self, input_ids, attention_mask=None, labels=None):
        outputs = super().forward(input_ids=input_ids, attention_mask=attention_mask)
        hidden_states = outputs[0]

        cls_output = hidden_states[:, 0, :]  
        logits = self.classifier(cls_output)

        loss = None
        if labels is not None:
            loss_fn = nn.CrossEntropyLoss()
            loss = loss_fn(logits, labels)

        return (loss, logits) if loss is not None else logits
    

class ClassificationDataset(Dataset):
    def __init__(self, data_file):
        with open(data_file, "r") as f:
            self.data = json.load(f)

        self.tokenizer = GPT2Tokenizer.from_pretrained("gpt2")

        # Add [CLS] token as a special token and resize model embeddings
        special_tokens_dict = {'cls_token': '[CLS]', 'pad_token': '[PAD]'}
        self.tokenizer.add_special_tokens(special_tokens_dict)
        
        self.label_map = {
            "Support Team": 0,
            "Finance Team": 1,
            "Product Development Team": 2
        }        

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        item = self.data[idx]
        text = "[CLS] " + item["prompt"]
        inputs = self.tokenizer.encode_plus(text, truncation=True, padding="max_length", max_length=1024, return_tensors="pt")
        
        label_id = self.label_map.get(item['response'], -1)
        if label_id == -1:
            raise ValueError(f"Invalid response: {item['response']}")
        
        return inputs["input_ids"].view(-1, 1024), inputs["attention_mask"].view(-1, 1024), torch.tensor(label_id)  
    
def train_classification_model(epochs=10):
    tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
    special_tokens_dict = {'cls_token': '[CLS]'}
    tokenizer.add_special_tokens(special_tokens_dict)

    model = GPT2ForClassification(num_labels=3, tokenizer=tokenizer).to(torch.device("cpu"))
    dataset = ClassificationDataset(data_file="GPT based triaging.json")
    tokenizer = dataset.tokenizer
    dataloader = DataLoader(dataset, batch_size=8, shuffle=True)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5, betas=(0.9, 0.95))

    for epoch in range(epochs):
        for batch in dataloader:
            input_ids, attention_mask, labels = batch
            loss, _ = model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()

    torch.save(model.state_dict(), "classification_model_params.pt")

train_classification_model()

# %%
model_path = "sft_model_params.pt"  # adjust path if needed
model = SFTModel()
model.load_state_dict(torch.load(model_path))
model.to(torch.device("cpu"))

# %%
# sentence = "Where is the option of new user in Nurturev?"  # Support team
# sentence = "I can't access my account." # Support team
# sentence = "The main page of Home app is not working. Make the corrections to rectify it." # Product Development Team
sentence = "There is some issue in the Home app. It stops as soon as it opens." # Product Development Team
prediction = model.predict(sentence)
print("Predicted Response:", prediction)

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)  # you might want to adjust learning rate

def fine_tune_on_feedback(prompt, correct_response, epochs=1):
    # Convert your single example into a format suitable for DataLoader
    feedback_dataset = [{"prompt": prompt, "response": correct_response}]
    feedback_loader = DataLoader(feedback_dataset, batch_size=1, shuffle=True)

    model.train()  # Set the model to training mode
    for epoch in range(epochs):
        for data in feedback_loader:
            prompt, response = data["prompt"], data["response"]
            loss = model.compute_loss(prompt, response)  # directly use this as loss
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()

# Here you'd provide the correct feedback
correct_response = "Product Development Team"
if prediction != correct_response:
    fine_tune_on_feedback(sentence, correct_response)

# %%
sentence = "There is some issue in the Home app. It stops as soon as it opens." # Product Development Team
prediction = model.predict(sentence)
print("Predicted Response:", prediction)

# %% [markdown]
# ### Neural Network

# %%
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.metrics import Recall

# %%
encoder = LabelEncoder()
y_encoded = encoder.fit_transform(y)
y_encoded = to_categorical(y_encoded) # One-hot encode the integer labels
X_encoded = list(use_model(X))

X_train, X_test, y_train, y_test = train_test_split(X_encoded, y_encoded, test_size=0.1, random_state=42)

# %%
model = Sequential()
model.add(Dense(512, input_dim=512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.6))
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(y_train.shape[1], activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(np.array(X_train), np.array(y_train), epochs=15, batch_size=16, verbose=1)
loss, accuracy = model.evaluate(np.array(X_test), np.array(y_test), verbose=0)

print(f"Loss: {loss}")
print(f"Accuracy: {accuracy}")

# %%
# Make predictions
y_pred = model.predict(np.array(X_test))
y_pred_labels = np.argmax(y_pred, axis=1)
y_test_labels = np.argmax(y_test, axis=1)

# Generate classification report
report = classification_report(y_test_labels, y_pred_labels, target_names=encoder.classes_)
print("Classification Report:")
print(report)

# %% [markdown]
# ## use the Roberta Method

# %%
from transformers import RobertaTokenizer, RobertaModel
import torch

# %%
tokenizer = RobertaTokenizer.from_pretrained("roberta-base")
model = RobertaModel.from_pretrained("roberta-base")

# %%
X = df['Request']
y = df['Team']

# %%
# Encode sentences using RoBERTa
X_encoded = []
for sentence in X:
    inputs = tokenizer(sentence, return_tensors="pt", padding="max_length", truncation=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
    sentence_embedding = outputs.last_hidden_state.mean(dim=1).squeeze().numpy()
    X_encoded.append(sentence_embedding)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.1, random_state=42)

# %%
param_grid = {
    'C': [5, 6, 7, 8, 9],
    'kernel': ['linear', 'rbf', 'sigmoid'],
    'gamma': ['scale', 'auto']
}

# %%
classifier = SVC()
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
grid_search = GridSearchCV(classifier, param_grid, cv=cv, scoring='accuracy')
grid_search.fit(X_train, y_train)

# %%
best_params = grid_search.best_params_
print(best_params)
best_classifier = grid_search.best_estimator_

# %%
y_pred = best_classifier.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"Best Parameters: {best_params}")
print(f"Accuracy: {accuracy}")
print("Classification Report:")
print(report)
